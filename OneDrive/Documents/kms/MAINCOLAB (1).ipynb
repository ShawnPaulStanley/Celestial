# %% [markdown]
# # NH3 / H2 Qubit Hamiltonian (Colab Minimal)
#
# This notebook now defers all logic to the repository code. Workflow:
#
# 1. Install pinned dependencies (Qiskit 2.x, qiskit-nature, PySCF).
# 2. Clone the repo.
# 3. Run the CLI script for NH3 (active space, 6 qubits) or H2 (4 qubits).
# 4. (Optional) Use fallback only (`--force-precomputed`) if PySCF fails.
#
# See repository README for details and provenance notes.

# %%
# === Master Environment + Repo Setup (Run FIRST) ===
import sys, subprocess, importlib, os, pathlib, numpy as np, shutil

# 1. Pin core quantum chemistry stack (idempotent)
PKGS = ['qiskit==2.1.2','qiskit-nature==0.7.2','pyscf==2.6.1','qiskit-aer']
subprocess.check_call([sys.executable,'-m','pip','install','--upgrade','--no-cache-dir']+PKGS)

# 2. Clone / update repo containing vqeskeletal.py (GroundStateFinder)
REPO_URL = 'https://github.com/Kukyos/GroundStateFinder.git'
REPO_DIR = pathlib.Path('GroundStateFinder')
if not REPO_DIR.exists():
    subprocess.check_call(['git','clone','--depth','1','--branch','main',REPO_URL])
else:
    try:
        subprocess.check_call(['git','-C',str(REPO_DIR),'pull','--ff-only'])
    except Exception as e:
        print('Git pull failed; forcing fresh clone:', e)
        try:
            shutil.rmtree(REPO_DIR, ignore_errors=True)
        except Exception as e2:
            print('Cleanup failed (continuing):', e2)
        subprocess.check_call(['git','clone','--depth','1','--branch','main',REPO_URL])

# 3. Ensure repo root and src on sys.path
paths_added = []
for p in [REPO_DIR, REPO_DIR/'src']:
    if p.exists() and str(p) not in sys.path:
        sys.path.insert(0, str(p))
        paths_added.append(str(p))
print('Added to sys.path:', paths_added)

# 4. Verify presence of vqeskeletal.py and patch missing base optimizer class if needed
vqefile = REPO_DIR/'vqeskeletal.py'
if not vqefile.exists():
    raise FileNotFoundError('FATAL: vqeskeletal.py not found in cloned repo; aborting.')
else:
    print('Found vqeskeletal.py at', vqefile)
    try:
        txt = vqefile.read_text(encoding='utf-8')
        if 'class ClassicalOptimizerPlugin' not in txt:
            print('Patching vqeskeletal.py: adding ClassicalOptimizerPlugin base...')
            insert_after = 'import warnings'
            base_def = (
                "\n\nclass ClassicalOptimizerPlugin:\n"
                "    \"\"\"Base class for classical optimizers used by VQE.\n\n"
                "    Concrete subclasses must implement `optimize(objective_function, initial_params)`\n"
                "    and return the optimized parameter vector as a NumPy array or list.\n"
                "    \"\"\"\n"
                "    def optimize(self, objective_function, initial_params):\n"
                "        raise NotImplementedError(\"Optimizers must implement optimize(objective_function, initial_params).\")\n\n"
            )
            if insert_after in txt:
                parts = txt.split(insert_after, 1)
                patched = parts[0] + insert_after + base_def + parts[1]
            else:
                patched = base_def + txt
            vqefile.write_text(patched, encoding='utf-8')
            print('Patched optimizer base inserted.')
    except Exception as ve:
        print('Verification/patch warning:', ve)

# 5. Core chemistry imports
from pyscf import gto, scf, ao2mo
from qiskit_nature.second_q.hamiltonians import ElectronicEnergy
from qiskit_nature.second_q.problems import ElectronicStructureProblem
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit.quantum_info import SparsePauliOp

# 6. Import repo module
import vqeskeletal as vsk
importlib.reload(vsk)

# 7. Version report
print('\nVersions:')
for mod_name in ['qiskit','qiskit_nature','pyscf','qiskit_aer']:
    try:
        m = importlib.import_module(mod_name)
        print(f'  {mod_name:14s}:', getattr(m,'__version__','?'))
    except Exception as e:
        print(f'  {mod_name:14s}: MISSING ({e})')

# 8. Shared constants (NH3 active space 6 qubits)
NH3_GEOM = 'N 0 0 0; H 0.9377 0 -0.3816; H -0.4688 0.8119 -0.3816; H -0.4688 -0.8119 -0.3816'
ELECTRONS_ALPHA = 2
ELECTRONS_BETA  = 2
ACTIVE_SPATIAL_ORBS = 3  # -> 6 spin orbitals

print('\nEnvironment + repository initialization complete.')
# Out:
# Added to sys.path: ['GroundStateFinder', 'GroundStateFinder/src']
# Found vqeskeletal.py at GroundStateFinder/vqeskeletal.py
#
# Versions:
#   qiskit        : 2.1.2
#   qiskit_nature : 0.7.2
#   pyscf         : 2.6.1
#   qiskit_aer    : 0.17.1
#
# Environment + repository initialization complete.

# %% [markdown]
# Direct NH3 6-qubit active-space build and Pauli expansion (no error handling).

# %% [markdown]
# ## Note
# Padding adds zero-coefficient Pauli strings to reach the requested minimum; physics unaffected.

# %%
# === 2. Build NH3 Active-Space Pauli Hamiltonian (Working Cell 2) ===
# Deterministic active-space construction (6 qubits) from PySCF integrals – NO FALLBACKS.

# SCF
mol = gto.M(atom=NH3_GEOM, basis='sto-3g', unit='Angstrom')
mf = scf.RHF(mol).run()
print(f'SCF energy: {mf.e_tot:.8f} Hartree')

# MO integrals
C = mf.mo_coeff
h_core_ao = mf.get_hcore()
h1_mo = C.T @ h_core_ao @ C
nmo = C.shape[1]
# 2-electron integrals (chemist) in MO basis
eri_mo_full = ao2mo.restore(1, ao2mo.full(mf._eri, C), nmo)

# Active space selection (first 3 spatial orbitals)
act = list(range(ACTIVE_SPATIAL_ORBS))
h1_act = h1_mo[np.ix_(act, act)]
eri_act = eri_mo_full[np.ix_(act, act, act, act)]

# Build ElectronicEnergy from raw integrals and wrap minimal problem info
# (We rely on qiskit-nature API directly; if this errors we STOP and fix.)
ee_act = ElectronicEnergy.from_raw_integrals(h1_act, eri_act)
problem_active = ElectronicStructureProblem(ee_act)

# Minimal wrapper supplying attributes AnsatzPlugin expects (accept flexible arg names)
class MiniProblem:
    def __init__(self, num_spin_orbitals=None, n_spin=None, num_alpha=None, n_alpha=None, num_beta=None, n_beta=None):
        self.num_spin_orbitals = num_spin_orbitals if num_spin_orbitals is not None else n_spin
        a = num_alpha if num_alpha is not None else n_alpha
        b = num_beta if num_beta is not None else n_beta
        self.num_particles = (a, b)
        if self.num_spin_orbitals is None or a is None or b is None:
            raise ValueError('MiniProblem requires spin orbitals and both particle counts.')

# Instantiate with explicit keywords
mini_problem = MiniProblem(num_spin_orbitals=2*ACTIVE_SPATIAL_ORBS,
                           num_alpha=ELECTRONS_ALPHA,
                           num_beta=ELECTRONS_BETA)

# Map fermionic Hamiltonian (robust to API return shape; still NO silent fallback)
mapper = JordanWignerMapper()
raw_ops = problem_active.second_q_ops()
print(f"second_q_ops() return type: {type(raw_ops)}")
if isinstance(raw_ops, dict):
    if 'ElectronicEnergy' not in raw_ops:
        raise KeyError("'ElectronicEnergy' key missing in second_q_ops() dict; keys: " + str(list(raw_ops.keys())))
    ferm_op = raw_ops['ElectronicEnergy']
elif isinstance(raw_ops, tuple):
    # Expect (main_op, aux_ops)
    if len(raw_ops) != 2:
        raise ValueError(f"Tuple from second_q_ops() length {len(raw_ops)} != 2; inspect manually.")
    ferm_op, aux_ops = raw_ops
    print(f"Extracted main fermionic operator from tuple; aux count: {len(aux_ops) if hasattr(aux_ops,'__len__') else 'N/A'}")
elif isinstance(raw_ops, list):
    if len(raw_ops) == 0:
        raise ValueError('Empty list from second_q_ops().')
    ferm_op = raw_ops[0]
    print('Warning: second_q_ops() returned list; using first element as main operator.')
else:
    raise TypeError(f"Unhandled type from second_q_ops(): {type(raw_ops)}")

qubit_op = mapper.map(ferm_op)

# Strict sanity checks (no silent fallbacks)
expected_qubits = 2 * ACTIVE_SPATIAL_ORBS
assert qubit_op.num_qubits == expected_qubits, f"Mapped qubits {qubit_op.num_qubits} != expected {expected_qubits}"
assert mini_problem.num_spin_orbitals == expected_qubits, "MiniProblem spin orbital mismatch"
assert sum(mini_problem.num_particles) == ELECTRONS_ALPHA + ELECTRONS_BETA, "Electron count mismatch"

# Term stats
labels = qubit_op.paulis.to_labels()
nonzero = [ (lbl, coeff) for lbl, coeff in zip(labels, qubit_op.coeffs) if abs(complex(coeff)) > 1e-12 ]
print(f"Qubits: {qubit_op.num_qubits}")
print(f"Non-zero Pauli terms: {len(nonzero)}")
print("Sample terms (first 10):")
for (lbl, coeff) in nonzero[:10]:
    print(f"  {coeff.real:+.8f} * {lbl}")

# System dictionary used downstream (NO fallbacks — this is the single source)
ham_system = {
    'problem_active': mini_problem,
    'mapper': mapper,
    'hamiltonian_active': qubit_op,
    'num_qubits': qubit_op.num_qubits,
    'basis': 'sto3g',
    'geometry': NH3_GEOM,
    'fallback': False
}
print('Hamiltonian system ready (use in later cells).')
# Out:
# converged SCF energy = -55.4540739617976
# SCF energy: -55.45407396 Hartree
# second_q_ops() return type: <class 'tuple'>
# Extracted main fermionic operator from tuple; aux count: 0
# Qubits: 6
# Non-zero Pauli terms: 62
# Sample terms (first 10):
#   -34.39753181 * IIIIII
#   +2.40316023 * IIIIZI
#   +11.07956840 * IIIIIZ
#   +0.19849215 * IIIIZZ
#   +2.03924408 * IIIZII
#   +0.17564461 * IIIZIZ
#   +0.12761114 * IIIIYY
#   +0.00469314 * IIIZYY
#   +0.12761114 * IIIIXX
#   +0.00469314 * IIIZXX
# Hamiltonian system ready (use in later cells).

# %% [markdown]
# ### Cell 3 Description: UCCSD Ansatz Construction
# Build the UCCSD excitation ansatz (with Hartree–Fock reference) sized to the previously created NH3 6‑qubit active-space Hamiltonian (`ham_system`).
#
# Inputs: `ham_system` dictionary containing mapped Pauli Hamiltonian & particle/orbital counts.
# Outputs: `uccsd_ansatz` (stored globally) ready for VQE; prints qubit count, parameter count, depth.
# No fallbacks: raises if ansatz can't be constructed.

# %%
# === 3. Build UCCSD Ansatz (Working Cell 3) ===
import importlib, vqeskeletal as vsk
importlib.reload(vsk)
from vqeskeletal import AnsatzPlugin

# Build ansatz from ham_system (expects mapper + mini problem)
ansatz = AnsatzPlugin(ansatz_reps=1, include_hf_state=True, verbose=True)
ansatz.build_from_hamiltonian(ham_system)
info = ansatz.get_ansatz_info()
print('Ansatz info:', {k: info[k] for k in ['num_qubits','num_parameters','circuit_depth','vqe_ready']})

# Store for later VQE runs
uccsd_ansatz = ansatz
print('Stored as uccsd_ansatz.')
# Out:
# ======================================================================
# BUILDING UCCSD ANSATZ FROM HAMILTONIAN
# ======================================================================
# System: qubits=6 spatial_orbs=3 particles=(2, 2)
# ✓ HF state ready (HartreeFock constructed)
# Ansatz depth=2 gates=5 params=8
# ✓ Ansatz construction complete (params=8)
# Ansatz info: {'num_qubits': 6, 'num_parameters': 8, 'circuit_depth': 2, 'vqe_ready': True}
# Stored as uccsd_ansatz.

# %% [markdown]
# ### Cell 3b Description: Optional Compact Ansatz Summary
# Generates an auxiliary UCCSD ansatz using helper utilities (`groundstate` package functions) to display a concise circuit/parameter preview. Safe to skip; does not affect later VQE cells. Purely informational.

# %%
# OPTIONAL: Compact UCCSD summary using provided helper utilities (repo already cloned)
import numpy as np, importlib
try:
    from groundstate import build_molecule_qubit_hamiltonian, uccsd_for_hamiltonian, circuit_summary
except ImportError:
    print('groundstate helpers not found (ensure repo cloned). Skipping summary.')
else:
    nh3_geom = NH3_GEOM
    ham = build_molecule_qubit_hamiltonian('NH3')
    ansatz_tmp, params_tmp = uccsd_for_hamiltonian(nh3_geom, ham, param_scale=0.02, seed=42)
    particles = ansatz_tmp.num_particles if isinstance(ansatz_tmp.num_particles,(tuple,list)) else (ansatz_tmp.num_particles, ansatz_tmp.num_particles)
    active_e = sum(particles)
    spatial = ansatz_tmp.num_spatial_orbitals
    print(f"Active space: {active_e} electrons, {spatial} orbitals -> {ansatz_tmp.num_qubits} qubits")
    print("Parameters:", np.array2string(params_tmp, separator=' ', max_line_width=120))
    print("\nCircuit (compact, high-level):")
    print(circuit_summary(ansatz_tmp, max_gates=25, decompose=False))
# Out:
# Active space: 4 electrons, 3 orbitals -> 6 qubits
# Parameters: [ 0.00609434 -0.02079968  0.01500902  0.01881129 -0.0390207  -0.02604359  0.00255681 -0.00632485]
#
# Circuit (compact, high-level):
# UCCSD: qubits=6 params=8 depth=1 (decomposed=False)
# Parameters: t[0], t[1], t[2], t[3], t[4], t[5], t[6], t[7]
#      ┌──────────────────────────────────────────────────────┐
# q_0: ┤0                                                     ├
#      │                                                      │
# q_1: ┤1                                                     ├
#      │                                                      │
# q_2: ┤2                                                     ├
#      │  EvolvedOps(t[0],t[1],t[2],t[3],t[4],t[5],t[6],t[7]) │
# q_3: ┤3                                                     ├
#      │                                                      │
# q_4: ┤4                                                     ├
#      │                                                      │
# q_5: ┤5                                                     ├
#      └──────────────────────────────────────────────────────┘

# %% [markdown]
# ### VQE Skeleton Integration
# Demonstrate integrating the repository's VQE skeleton (`vqeskeletal.py`) with a simple optimizer plugin.
#
# This cell will:
# 1. Ensure the repo clone is present / updated.
# 2. Import the skeleton classes.
# 3. Define a minimal gradient-free optimizer (coordinate search) that fits the plugin interface.
# 4. Build the Hamiltonian + UCCSD ansatz via the skeleton plugins.
# 5. Run a mock VQE (note: expectation function is a placeholder returning 0.0 in the skeleton).
#
# You can later replace the placeholder expectation with a real Estimator evaluation and plug in a hybrid (global→local) optimizer.

# %% [markdown]
# ### Cell 4 Description: Coordinate-Descent VQE Integration
# Rebuilds a fresh UCCSD ansatz plugin from `ham_system`, wraps the Hamiltonian with a direct plugin, performs an Estimator sanity check, then runs a lightweight coordinate-descent optimization (no stochastic SPSA here). Provides an initial exact estimator energy and improvement after local search. Raises if any estimator anomaly is detected.

# %%
# === VQE Skeleton Integration (REAL Hamiltonian, NO FALLBACK) ===

# Uses the previously built `ham_system` (Cell 2) and REBUILDS a fresh UCCSD ansatz locally.
# If you see an energy near -5, the estimator path failed — we raise immediately.


import importlib, numpy as np, vqeskeletal as vsk
from vqeskeletal import AnsatzPlugin, ZNEDenoiserPlugin, VQE
from qiskit.quantum_info import SparsePauliOp


# Assert prerequisites
assert 'ham_system' in globals(), 'ham_system missing (run Cell 2)'


# Minimal direct Hamiltonian plugin wrapper (no internal reconstruction)
class DirectHamPlugin:
    def __init__(self, system_dict):
        self.system_dict = system_dict
    def get_hamiltonian(self):
        return self.system_dict

# Coordinate Descent Optimizer (unchanged logic, but clearer prints)
class CoordinateDescentOptimizer(vsk.ClassicalOptimizerPlugin):
    def __init__(self, max_iters=8, step=0.25, shrink=0.5, tol=1e-6, verbose=True):
        self.max_iters=max_iters; self.step=step; self.shrink=shrink; self.tol=tol; self.verbose=verbose
    def optimize(self, objective_function, initial_params):
        params = np.array(initial_params, dtype=float)
        best_val = objective_function(params); step=self.step
        if self.verbose: print(f'[CD] Initial energy: {best_val:.10f}')
        for it in range(self.max_iters):
            improved=False
            for i in range(len(params)):
                for d in (+1,-1):
                    trial = params.copy(); trial[i]+=d*step
                    val=objective_function(trial)
                    if val < best_val - self.tol:
                        best_val=val; params=trial; improved=True
                        if self.verbose: print(f'[CD] iter {it} param {i} {"+" if d>0 else "-"} -> {best_val:.10f}')
            if not improved:
                step*=self.shrink
                if self.verbose: print(f'[CD] No improvement; shrink step -> {step}')
                if step < self.tol:
                    if self.verbose: print('[CD] Converged (step below tol)')
                    break
        return params

# Rebuild ansatz plugin from real ham_system (independent copy)
ansatz_plugin = AnsatzPlugin(ansatz_reps=1, include_hf_state=True, verbose=False)
ansatz_plugin.build_from_hamiltonian(ham_system)
info = ansatz_plugin.get_ansatz_info()
print('Ansatz info (direct):', {k: info[k] for k in ['num_qubits','num_parameters','circuit_depth','vqe_ready']})
assert info['vqe_ready'], 'Ansatz not VQE-ready'

# Prepare plugins
ham_plugin = DirectHamPlugin(ham_system)
zne_plugin = ZNEDenoiserPlugin(noise_factors=[1.0], extrapolation_method='linear', verbose=False)
coord_opt = CoordinateDescentOptimizer(max_iters=8, step=0.25, shrink=0.5, tol=1e-6, verbose=True)

# Instantiate VQE and run
vqe_instance = VQE(ansatz_plugin, ham_plugin, coord_opt, zne_plugin, verbose=True)

# Initial parameters
init = ansatz_plugin.get_initial_parameters('zero')  # HF-based start

# Sanity: direct estimator energy BEFORE optimization
try:
    from qiskit_aer.primitives import Estimator
    est = Estimator()
    trial0 = ansatz_plugin.get_trial_wavefunction(init)
    e0 = est.run([trial0],[ham_system['hamiltonian_active']]).result().values[0]
    print(f'Initial estimator energy (raw) = {e0:.10f} Hartree')
    if abs(e0 + 5) < 0.5:
        raise RuntimeError('Estimator returned suspicious ~-5 energy (placeholder). Investigate measurement path.')
except Exception as ee:
    print('Estimator pre-check failed:', ee)
    raise

# Optimize
opt_params = coord_opt.optimize(vqe_instance.objective_function, init)
final_energy = vqe_instance.objective_function(opt_params)
print('\n[CoordinateDescent VQE] Final energy:', f'{final_energy:.10f}')
print('[CoordinateDescent VQE] Improvement:', f'{(e0-final_energy):.10f} Hartree')

# Expose for summary table
vqe_cd = vqe_instance
energy_cd = final_energy
# Out:
# Ansatz info (direct): {'num_qubits': 6, 'num_parameters': 8, 'circuit_depth': 2, 'vqe_ready': True}
# 🔄 Initializing VQE system...
# ✓ Quantum estimator setup complete (Qiskit Aer)
# Initial estimator energy (raw) = -56.3524085172 Hartree
#
# ============================================================
# 🔄 VQE ITERATION 1
# ============================================================
# 📊 Energy = -56.34350345 Hartree
# 📊 Energy = -35356.0555 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94597164 Hartree
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.0000]
#    Parameter variance:  0.0000
#    RMS parameter:  0.0000
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
# [CD] Initial energy: -56.3435034487
#
# ============================================================
# 🔄 VQE ITERATION 2
# ============================================================
# 📊 Energy = -55.35681804 Hartree
# 📊 Energy = -34736.9015 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.95928623 Hartree
# 📈 Energy improvement: -0.98668540 Hartree (-619.1540 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.2500 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 3
# ============================================================
# 📊 Energy = -55.35681804 Hartree
# 📊 Energy = -34736.9015 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.95928623 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]=-0.2500 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 4
# ============================================================
# 📊 Energy = -56.30787584 Hartree
# 📊 Energy = -35333.6989 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.91034402 Hartree
# 📈 Energy improvement: 0.95105779 Hartree (596.7973 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.2500 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 5
# ============================================================
# 📊 Energy = -56.30787584 Hartree
# 📊 Energy = -35333.6989 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.91034402 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.2500 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 6
# ============================================================
# 📊 Energy = -55.35681804 Hartree
# 📊 Energy = -34736.9015 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.95928623 Hartree
# 📈 Energy improvement: -0.95105779 Hartree (-596.7973 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.2500 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 7
# ============================================================
# 📊 Energy = -55.35681804 Hartree
# 📊 Energy = -34736.9015 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.95928623 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.2500 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 8
# ============================================================
# 📊 Energy = -56.30787584 Hartree
# 📊 Energy = -35333.6989 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.91034402 Hartree
# 📈 Energy improvement: 0.95105779 Hartree (596.7973 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.2500
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 9
# ============================================================
# 📊 Energy = -56.30787584 Hartree
# 📊 Energy = -35333.6989 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.91034402 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.2500
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 10
# ============================================================
# 📊 Energy = -54.16450709 Hartree
# 📊 Energy = -33988.7157 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.76697527 Hartree
# 📈 Energy improvement: -2.14336875 Hartree (-1344.9832 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.2500 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 11
# ============================================================
# 📊 Energy = -54.17349242 Hartree
# 📊 Energy = -33994.3541 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.77596060 Hartree
# 📈 Energy improvement: 0.00898533 Hartree (5.6384 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.2500 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 12
# ============================================================
# 📊 Energy = -55.30481831 Hartree
# 📊 Energy = -34704.2712 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.90728649 Hartree
# 📈 Energy improvement: 1.13132589 Hartree (709.9172 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.2500 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 13
# ============================================================
# 📊 Energy = -55.31931201 Hartree
# 📊 Energy = -34713.3662 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.92178019 Hartree
# 📈 Energy improvement: 0.01449370 Hartree (9.0949 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.2500 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 14
# ============================================================
# 📊 Energy = -55.30481831 Hartree
# 📊 Energy = -34704.2712 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.90728649 Hartree
# 📈 Energy improvement: -0.01449370 Hartree (-9.0949 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.2500 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 15
# ============================================================
# 📊 Energy = -55.31931201 Hartree
# 📊 Energy = -34713.3662 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.92178019 Hartree
# 📈 Energy improvement: 0.01449370 Hartree (9.0949 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.2500 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 16
# ============================================================
# 📊 Energy = -56.20782947 Hartree
# 📊 Energy = -35270.9189 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.81029766 Hartree
# 📈 Energy improvement: 0.88851746 Hartree (557.5527 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.2500
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 17
# ============================================================
# 📊 Energy = -56.32776189 Hartree
# 📊 Energy = -35346.1775 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93023007 Hartree
# 📈 Energy improvement: 0.11993242 Hartree (75.2587 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.2500
#    ==================================================
# [CD] No improvement; shrink step -> 0.125
#
# ============================================================
# 🔄 VQE ITERATION 18
# ============================================================
# 📊 Energy = -56.09293735 Hartree
# 📊 Energy = -35198.8230 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69540554 Hartree
# 📈 Energy improvement: -0.23482453 Hartree (-147.3545 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.1250 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 19
# ============================================================
# 📊 Energy = -56.09293735 Hartree
# 📊 Energy = -35198.8230 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69540554 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]=-0.1250 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 20
# ============================================================
# 📊 Energy = -56.33445591 Hartree
# 📊 Energy = -35350.3781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93692410 Hartree
# 📈 Energy improvement: 0.24151856 Hartree (151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.1250 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 21
# ============================================================
# 📊 Energy = -56.33445591 Hartree
# 📊 Energy = -35350.3781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93692410 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.1250 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 22
# ============================================================
# 📊 Energy = -56.09293735 Hartree
# 📊 Energy = -35198.8230 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69540554 Hartree
# 📈 Energy improvement: -0.24151856 Hartree (-151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.1250 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 23
# ============================================================
# 📊 Energy = -56.09293735 Hartree
# 📊 Energy = -35198.8230 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69540554 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.1250 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 24
# ============================================================
# 📊 Energy = -56.33445591 Hartree
# 📊 Energy = -35350.3781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93692410 Hartree
# 📈 Energy improvement: 0.24151856 Hartree (151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.1250
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 25
# ============================================================
# 📊 Energy = -56.33445591 Hartree
# 📊 Energy = -35350.3781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93692410 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.1250
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 26
# ============================================================
# 📊 Energy = -55.78897569 Hartree
# 📊 Energy = -35008.0843 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.39144388 Hartree
# 📈 Energy improvement: -0.54548022 Hartree (-342.2937 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.1250 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 27
# ============================================================
# 📊 Energy = -55.79361250 Hartree
# 📊 Energy = -35010.9940 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.39608069 Hartree
# 📈 Energy improvement: 0.00463681 Hartree (2.9096 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.1250 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 28
# ============================================================
# 📊 Energy = -56.07783279 Hartree
# 📊 Energy = -35189.3448 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68030098 Hartree
# 📈 Energy improvement: 0.28422029 Hartree (178.3508 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.1250 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 29
# ============================================================
# 📊 Energy = -56.08531216 Hartree
# 📊 Energy = -35194.0381 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68778035 Hartree
# 📈 Energy improvement: 0.00747937 Hartree (4.6934 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.1250 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 30
# ============================================================
# 📊 Energy = -56.07783279 Hartree
# 📊 Energy = -35189.3448 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68030098 Hartree
# 📈 Energy improvement: -0.00747937 Hartree (-4.6934 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.1250 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 31
# ============================================================
# 📊 Energy = -56.08531216 Hartree
# 📊 Energy = -35194.0381 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68778035 Hartree
# 📈 Energy improvement: 0.00747937 Hartree (4.6934 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.1250 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 32
# ============================================================
# 📊 Energy = -56.29333255 Hartree
# 📊 Energy = -35324.5728 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89580074 Hartree
# 📈 Energy improvement: 0.20802039 Hartree (130.5347 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 33
# ============================================================
# 📊 Energy = -56.35522278 Hartree
# 📊 Energy = -35363.4095 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95769096 Hartree
# 📈 Energy improvement: 0.06189023 Hartree (38.8367 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
# [CD] iter 1 param 7 - -> -56.3552227770
#
# ============================================================
# 🔄 VQE ITERATION 34
# ============================================================
# 📊 Energy = -56.10447452 Hartree
# 📊 Energy = -35206.0627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70694270 Hartree
# 📈 Energy improvement: -0.25074826 Hartree (-157.3468 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.1250 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 35
# ============================================================
# 📊 Energy = -56.10447452 Hartree
# 📊 Energy = -35206.0627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70694270 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]=-0.1250 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 36
# ============================================================
# 📊 Energy = -56.34599308 Hartree
# 📊 Energy = -35357.6178 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94846127 Hartree
# 📈 Energy improvement: 0.24151856 Hartree (151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.1250 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 37
# ============================================================
# 📊 Energy = -56.34599308 Hartree
# 📊 Energy = -35357.6178 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94846127 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.1250 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 38
# ============================================================
# 📊 Energy = -56.10447452 Hartree
# 📊 Energy = -35206.0627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70694270 Hartree
# 📈 Energy improvement: -0.24151856 Hartree (-151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.1250 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 39
# ============================================================
# 📊 Energy = -56.10447452 Hartree
# 📊 Energy = -35206.0627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70694270 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.1250 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 40
# ============================================================
# 📊 Energy = -56.34599308 Hartree
# 📊 Energy = -35357.6178 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94846127 Hartree
# 📈 Energy improvement: 0.24151856 Hartree (151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.1250
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 41
# ============================================================
# 📊 Energy = -56.34599308 Hartree
# 📊 Energy = -35357.6178 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94846127 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.1250
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 42
# ============================================================
# 📊 Energy = -55.80193058 Hartree
# 📊 Energy = -35016.2137 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.40439877 Hartree
# 📈 Energy improvement: -0.54406250 Hartree (-341.4041 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.1250 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 43
# ============================================================
# 📊 Energy = -55.80373195 Hartree
# 📊 Energy = -35017.3440 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.40620013 Hartree
# 📈 Energy improvement: 0.00180136 Hartree (1.1304 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.1250 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 44
# ============================================================
# 📊 Energy = -56.08702573 Hartree
# 📊 Energy = -35195.1134 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68949392 Hartree
# 📈 Energy improvement: 0.28329379 Hartree (177.7694 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.1250 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 45
# ============================================================
# 📊 Energy = -56.09919355 Hartree
# 📊 Energy = -35202.7488 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70166174 Hartree
# 📈 Energy improvement: 0.01216782 Hartree (7.6354 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.1250 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 46
# ============================================================
# 📊 Energy = -56.08702573 Hartree
# 📊 Energy = -35195.1134 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68949392 Hartree
# 📈 Energy improvement: -0.01216782 Hartree (-7.6354 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.1250 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 47
# ============================================================
# 📊 Energy = -56.09919355 Hartree
# 📊 Energy = -35202.7488 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70166174 Hartree
# 📈 Energy improvement: 0.01216782 Hartree (7.6354 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.1250 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 48
# ============================================================
# 📊 Energy = -56.34350345 Hartree
# 📊 Energy = -35356.0555 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94597164 Hartree
# 📈 Energy improvement: 0.24430990 Hartree (153.3067 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.0000]
#    Parameter variance:  0.0000
#    RMS parameter:  0.0000
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 49
# ============================================================
# 📊 Energy = -56.32776189 Hartree
# 📊 Energy = -35346.1775 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93023007 Hartree
# 📈 Energy improvement: -0.01574156 Hartree (-9.8780 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.2500
#    ==================================================
# [CD] No improvement; shrink step -> 0.0625
#
# ============================================================
# 🔄 VQE ITERATION 50
# ============================================================
# 📊 Energy = -56.29229020 Hartree
# 📊 Energy = -35323.9187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89475839 Hartree
# 📈 Energy improvement: -0.03547168 Hartree (-22.2588 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0625 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 51
# ============================================================
# 📊 Energy = -56.29229020 Hartree
# 📊 Energy = -35323.9187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89475839 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]=-0.0625 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 52
# ============================================================
# 📊 Energy = -56.35290632 Hartree
# 📊 Energy = -35361.9559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95537450 Hartree
# 📈 Energy improvement: 0.06061611 Hartree (38.0372 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0625 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 53
# ============================================================
# 📊 Energy = -56.35290632 Hartree
# 📊 Energy = -35361.9559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95537450 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.0625 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 54
# ============================================================
# 📊 Energy = -56.29229020 Hartree
# 📊 Energy = -35323.9187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89475839 Hartree
# 📈 Energy improvement: -0.06061611 Hartree (-38.0372 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0625 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 55
# ============================================================
# 📊 Energy = -56.29229020 Hartree
# 📊 Energy = -35323.9187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89475839 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.0625 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 56
# ============================================================
# 📊 Energy = -56.35290632 Hartree
# 📊 Energy = -35361.9559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95537450 Hartree
# 📈 Energy improvement: 0.06061611 Hartree (38.0372 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0625
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 57
# ============================================================
# 📊 Energy = -56.35290632 Hartree
# 📊 Energy = -35361.9559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95537450 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.0625
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 58
# ============================================================
# 📊 Energy = -56.21613016 Hartree
# 📊 Energy = -35276.1276 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.81859835 Hartree
# 📈 Energy improvement: -0.13677615 Hartree (-85.8283 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0625 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 59
# ============================================================
# 📊 Energy = -56.21703793 Hartree
# 📊 Energy = -35276.6973 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.81950612 Hartree
# 📈 Energy improvement: 0.00090776 Hartree (0.5696 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.0625 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 60
# ============================================================
# 📊 Energy = -56.28637198 Hartree
# 📊 Energy = -35320.2050 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.88884017 Hartree
# 📈 Energy improvement: 0.06933405 Hartree (43.5077 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0625 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 61
# ============================================================
# 📊 Energy = -56.29250373 Hartree
# 📊 Energy = -35324.0527 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89497192 Hartree
# 📈 Energy improvement: 0.00613175 Hartree (3.8477 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.0625 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 62
# ============================================================
# 📊 Energy = -56.28637198 Hartree
# 📊 Energy = -35320.2050 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.88884017 Hartree
# 📈 Energy improvement: -0.00613175 Hartree (-3.8477 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0625 θ[ 7]=-0.1250
#    ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4124998971.py in <cell line: 0>()
#      78
#      79 # Optimize
# ---> 80 opt_params = coord_opt.optimize(vqe_instance.objective_function, init)
#      81 final_energy = vqe_instance.objective_function(opt_params)
#      82 print('\n[CoordinateDescent VQE] Final energy:', f'{final_energy:.10f}')
#
# /tmp/ipython-input-4124998971.py in optimize(self, objective_function, initial_params)
#      34                 for d in (+1,-1):
#      35                     trial = params.copy(); trial[i]+=d*step
# ---> 36                     val=objective_function(trial)
#      37                     if val < best_val - self.tol:
#      38                         best_val=val; params=trial; improved=True
#
# /content/GroundStateFinder/vqeskeletal.py in objective_function(self, parameters)
#    1312         else:
#    1313             # Single-factor (legacy) path
# -> 1314             single_val = self._simulate_measurement(trial_wavefunction, hamiltonian)
#    1315             try:
#    1316                 single_val = float(single_val)
#
# /content/GroundStateFinder/vqeskeletal.py in _simulate_measurement(self, trial_wavefunction, hamiltonian)
#    1191             except TypeError:
#    1192                 job = self.estimator.run([(trial_wavefunction, hamiltonian)])
# -> 1193             estimator_result = job.result()
#    1194
#    1195             def collect_numbers(obj, depth=0, found=None):
#
# /usr/local/lib/python3.12/dist-packages/qiskit/primitives/primitive_job.py in result(self)
#      63         if self._result is None:
#      64             self._check_submitted()
# ---> 65             self._result = self._future.result()
#      66         return self._result
#      67
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Cell 4a Description: Baseline Minimal VQE (No UCCSD)
# Runs the simplest possible VQE loop on the NH3 Hamiltonian with a hardware-efficient layered Ry + CNOT ladder ansatz (depth=2 by default). Provides a quick reference energy and timing before UCCSD-based variants. Adjustable via NUM_LAYERS. No ZNE, no hybrid switching.

# %%
# === 4a. Simple VQE (Generic HEA, No Chemistry Ansatz, With Noise) ===
# This variant uses a hardware-efficient ansatz (Ry+CX) with no chemistry priors, and simulates noise.
from vqeskeletal import VQE, ZNEDenoiserPlugin, SPSAOptimizer, GenericAnsatzPlugin
from qiskit_aer.primitives import Estimator
from qiskit_aer.noise import NoiseModel, depolarizing_error
import numpy as np

assert 'ham_system' in globals(), 'Run the Hamiltonian build cell first.'

# Build hardware-efficient ansatz (Ry+CX, 2 layers)
generic = GenericAnsatzPlugin(layers=2, entanglement='linear', verbose=True)
generic.build_from_hamiltonian(ham_system)
print(f"[Simple VQE] HEA ansatz: qubits={generic.num_qubits}, params={generic.num_parameters}, layers={generic.layers}")

# Simulate depolarizing noise on all qubits and gates
def make_noise_model(p1=0.01, p2=0.02):
    model = NoiseModel()
    model.add_all_qubit_quantum_error(depolarizing_error(p1, 1), ['rx', 'ry', 'rz', 'x', 'y', 'z'])
    model.add_all_qubit_quantum_error(depolarizing_error(p2, 2), ['cx'])
    return model

noise_model = make_noise_model()
# Qiskit Aer Estimator (2.x): configure noise and shots via backend_options/run_options
estimator = Estimator(backend_options={"noise_model": noise_model}, run_options={"shots": 2048})

class DirectHam:
    def __init__(self, sysd): self.sysd = sysd
    def get_hamiltonian(self): return self.sysd

BASIC_SPSA_ITERS = 100
basic_optimizer = SPSAOptimizer(max_iter=BASIC_SPSA_ITERS, a=0.25, c=0.15, tol=5e-4, verbose=True)
no_zne = ZNEDenoiserPlugin(noise_factors=[1.0], extrapolation_method='linear', verbose=False)

vqe_simple = VQE(generic, DirectHam(ham_system), basic_optimizer, no_zne, verbose=True, estimator=estimator)
init_simple = generic.get_initial_parameters('zero')
params_simple, energy_simple = vqe_simple.run(init_simple)

shift = getattr(vqe_simple, 'energy_constant_shift', 0.0) or 0.0
print('\n[Simple VQE] Final total energy (raw):', f'{energy_simple:.10f} Hartree')
print('[Simple VQE] Final energy (minus constant shift', f'{shift:.6f}', '):', f'{(energy_simple-shift):.10f} Hartree')

# Expose for summary table
energy_simple = float(energy_simple)
# Out:
# ✓ Generic ansatz built (layers=2, entanglement=linear, params=12)
# [Simple VQE] HEA ansatz: qubits=6, params=12, layers=2
# 🔄 Initializing VQE system...
# ✓ Generic ansatz built (layers=2, entanglement=linear, params=12)
#
# 🚀 Starting VQE optimization run
#    Parameter count: 12
#    Optimizer: SPSAOptimizer
#
# ============================================================
# 🔄 VQE ITERATION 1
# ============================================================
# 📊 Energy = -0.00000000 Hartree
# 📊 Energy = -0.0000 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 34.39753181 Hartree
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [ 0.0000,  0.0000]
#    Parameter variance:  0.0000
#    RMS parameter:  0.0000
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#      ... and 4 more parameters
#    ==================================================
# [SPSA] Initial energy: -4.440892098500626e-15
#
# ============================================================
# 🔄 VQE ITERATION 2
# ============================================================
# 📊 Energy = -1.63649218 Hartree
# 📊 Energy = -1026.9136 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 32.76103963 Hartree
# 📈 Energy improvement: 1.63649218 Hartree (1026.9136 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.1500,  0.1500]
#    Parameter variance:  0.0169
#    RMS parameter:  0.1500
#    Parameters:
#      θ[ 0]=-0.1500 θ[ 1]= 0.1500 θ[ 2]=-0.1500 θ[ 3]= 0.1500
#      θ[ 4]= 0.1500 θ[ 5]= 0.1500 θ[ 6]= 0.1500 θ[ 7]= 0.1500
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 3
# ============================================================
# 📊 Energy = -1.97079219 Hartree
# 📊 Energy = -1236.6898 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 32.42673962 Hartree
# 📈 Energy improvement: 0.33430001 Hartree (209.7763 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.1500,  0.1500]
#    Parameter variance:  0.0169
#    RMS parameter:  0.1500
#    Parameters:
#      θ[ 0]= 0.1500 θ[ 1]=-0.1500 θ[ 2]= 0.1500 θ[ 3]=-0.1500
#      θ[ 4]=-0.1500 θ[ 5]=-0.1500 θ[ 6]=-0.1500 θ[ 7]=-0.1500
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 4
# ============================================================
# 📊 Energy = -6.60418125 Hartree
# 📊 Energy = -4144.1832 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 27.79335056 Hartree
# 📈 Energy improvement: 4.63338906 Hartree (2907.4933 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.2786,  0.2786]
#    Parameter variance:  0.0582
#    RMS parameter:  0.2786
#    Parameters:
#      θ[ 0]= 0.2786 θ[ 1]=-0.2786 θ[ 2]= 0.2786 θ[ 3]=-0.2786
#      θ[ 4]=-0.2786 θ[ 5]=-0.2786 θ[ 6]=-0.2786 θ[ 7]=-0.2786
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  1 energy=-6.60418125 ΔE=6.604e+00 ak=2.500e-01 ck=1.500e-01
#
# ============================================================
# 🔄 VQE ITERATION 5
# ============================================================
# 📊 Energy = -6.77686801 Hartree
# 📊 Energy = -4252.5457 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 27.62066380 Hartree
# 📈 Energy improvement: 0.17268676 Hartree (108.3625 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.4184,  0.1387]
#    Parameter variance:  0.0534
#    RMS parameter:  0.3117
#    Parameters:
#      θ[ 0]= 0.1387 θ[ 1]=-0.4184 θ[ 2]= 0.1387 θ[ 3]=-0.4184
#      θ[ 4]=-0.1387 θ[ 5]=-0.4184 θ[ 6]=-0.1387 θ[ 7]=-0.4184
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 6
# ============================================================
# 📊 Energy = -8.25068924 Hartree
# 📊 Energy = -5177.3818 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 26.14684258 Hartree
# 📈 Energy improvement: 1.47382123 Hartree (924.8361 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.4184,  0.4184]
#    Parameter variance:  0.0924
#    RMS parameter:  0.3117
#    Parameters:
#      θ[ 0]= 0.4184 θ[ 1]=-0.1387 θ[ 2]= 0.4184 θ[ 3]=-0.1387
#      θ[ 4]=-0.4184 θ[ 5]=-0.1387 θ[ 6]=-0.4184 θ[ 7]=-0.1387
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 7
# ============================================================
# 📊 Energy = -29.48540173 Hartree
# 📊 Energy = -18502.3550 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 4.91213009 Hartree
# 📈 Energy improvement: 21.23471249 Hartree (13324.9732 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-1.1464,  1.1464]
#    Parameter variance:  0.7440
#    RMS parameter:  0.9115
#    Parameters:
#      θ[ 0]= 1.1464 θ[ 1]= 0.5893 θ[ 2]= 1.1464 θ[ 3]= 0.5893
#      θ[ 4]=-1.1464 θ[ 5]= 0.5893 θ[ 6]=-1.1464 θ[ 7]= 0.5893
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  2 energy=-29.48540173 ΔE=2.288e+01 ak=1.647e-01 ck=1.399e-01
#
# ============================================================
# 🔄 VQE ITERATION 8
# ============================================================
# 📊 Energy = -25.34891171 Hartree
# 📊 Energy = -15906.6702 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 9.04862010 Hartree
# 📈 Energy improvement: -4.13649002 Hartree (-2595.6847 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-1.2807,  1.0122]
#    Parameter variance:  0.7497
#    RMS parameter:  0.9077
#    Parameters:
#      θ[ 0]= 1.0122 θ[ 1]= 0.7235 θ[ 2]= 1.0122 θ[ 3]= 0.7235
#      θ[ 4]=-1.2807 θ[ 5]= 0.7235 θ[ 6]=-1.0122 θ[ 7]= 0.4550
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 9
# ============================================================
# 📊 Energy = -34.05059731 Hartree
# 📊 Energy = -21367.0563 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 0.34693450 Hartree
# 📈 Energy improvement: 8.70168561 Hartree (5460.3860 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-1.2807,  1.2807]
#    Parameter variance:  0.7732
#    RMS parameter:  0.9347
#    Parameters:
#      θ[ 0]= 1.2807 θ[ 1]= 0.4550 θ[ 2]= 1.2807 θ[ 3]= 0.4550
#      θ[ 4]=-1.0122 θ[ 5]= 0.4550 θ[ 6]=-1.2807 θ[ 7]= 0.7235
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 10
# ============================================================
# 📊 Energy = -33.52866611 Hartree
# 📊 Energy = -21039.5397 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 0.86886570 Hartree
# 📈 Energy improvement: -0.52193120 Hartree (-327.5165 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-5.3284,  5.3284]
#    Parameter variance: 18.1133
#    RMS parameter:  4.3700
#    Parameters:
#      θ[ 0]= 5.3284 θ[ 1]=-3.5927 θ[ 2]= 5.3284 θ[ 3]=-3.5927
#      θ[ 4]= 3.0356 θ[ 5]=-3.5927 θ[ 6]=-5.3284 θ[ 7]= 4.7713
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  3 energy=-33.52866611 ΔE=4.043e+00 ak=1.290e-01 ck=1.342e-01
#
# ============================================================
# 🔄 VQE ITERATION 11
# ============================================================
# 📊 Energy = -34.94787051 Hartree
# 📊 Energy = -21930.1033 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -0.55033869 Hartree
# 📈 Energy improvement: 1.41920440 Hartree (890.5635 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-5.1980,  5.4588]
#    Parameter variance: 17.7744
#    RMS parameter:  4.3360
#    Parameters:
#      θ[ 0]= 5.1980 θ[ 1]=-3.4623 θ[ 2]= 5.4588 θ[ 3]=-3.7231
#      θ[ 4]= 2.9052 θ[ 5]=-3.4623 θ[ 6]=-5.1980 θ[ 7]= 4.9017
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 12
# ============================================================
# 📊 Energy = -32.43607656 Hartree
# 📊 Energy = -20353.9300 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 1.96145525 Hartree
# 📈 Energy improvement: -2.51179394 Hartree (-1576.1733 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-5.4588,  5.4588]
#    Parameter variance: 18.4853
#    RMS parameter:  4.4075
#    Parameters:
#      θ[ 0]= 5.4588 θ[ 1]=-3.7231 θ[ 2]= 5.1980 θ[ 3]=-3.4623
#      θ[ 4]= 3.1660 θ[ 5]=-3.7231 θ[ 6]=-5.4588 θ[ 7]= 4.6409
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 13
# ============================================================
# 📊 Energy = -39.50091359 Hartree
# 📊 Energy = -24787.1788 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.10338177 Hartree
# 📈 Energy improvement: 7.06483702 Hartree (4433.2488 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.6379,  6.3736]
#    Parameter variance: 16.3265
#    RMS parameter:  4.2054
#    Parameters:
#      θ[ 0]= 4.2833 θ[ 1]=-2.5476 θ[ 2]= 6.3736 θ[ 3]=-4.6379
#      θ[ 4]= 1.9904 θ[ 5]=-2.5476 θ[ 6]=-4.2833 θ[ 7]= 5.8164
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  4 energy=-39.50091359 ΔE=5.972e+00 ak=1.085e-01 ck=1.304e-01
#
# ============================================================
# 🔄 VQE ITERATION 14
# ============================================================
# 📊 Energy = -35.74481433 Hartree
# 📊 Energy = -22430.1927 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -1.34728252 Hartree
# 📈 Energy improvement: -3.75609925 Hartree (-2356.9861 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.7654,  6.2461]
#    Parameter variance: 16.4373
#    RMS parameter:  4.2014
#    Parameters:
#      θ[ 0]= 4.1558 θ[ 1]=-2.6751 θ[ 2]= 6.2461 θ[ 3]=-4.7654
#      θ[ 4]= 1.8629 θ[ 5]=-2.6751 θ[ 6]=-4.1558 θ[ 7]= 5.9439
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 15
# ============================================================
# 📊 Energy = -42.12996570 Hartree
# 📊 Energy = -26436.9326 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.73243388 Hartree
# 📈 Energy improvement: 6.38515136 Hartree (4006.7399 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.5104,  6.5011]
#    Parameter variance: 16.2402
#    RMS parameter:  4.2133
#    Parameters:
#      θ[ 0]= 4.4108 θ[ 1]=-2.4201 θ[ 2]= 6.5011 θ[ 3]=-4.5104
#      θ[ 4]= 2.1179 θ[ 5]=-2.4201 θ[ 6]=-4.4108 θ[ 7]= 5.6889
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 16
# ============================================================
# 📊 Energy = -30.10470003 Hartree
# 📊 Energy = -18890.9702 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 4.29283179 Hartree
# 📈 Energy improvement: -12.02526567 Hartree (-7545.9624 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.6591,  8.7494]
#    Parameter variance: 18.7233
#    RMS parameter:  4.9258
#    Parameters:
#      θ[ 0]= 6.6591 θ[ 1]=-0.1718 θ[ 2]= 8.7494 θ[ 3]=-2.2621
#      θ[ 4]= 4.3662 θ[ 5]=-0.1718 θ[ 6]=-6.6591 θ[ 7]= 3.4406
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  5 energy=-30.10470003 ΔE=-9.396e+00 ak=9.488e-02 ck=1.275e-01
#
# ============================================================
# 🔄 VQE ITERATION 17
# ============================================================
# 📊 Energy = -30.96119266 Hartree
# 📊 Energy = -19428.4270 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 3.43633915 Hartree
# 📈 Energy improvement: 0.85649263 Hartree (537.4568 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.7843,  8.8745]
#    Parameter variance: 19.5166
#    RMS parameter:  5.0254
#    Parameters:
#      θ[ 0]= 6.7843 θ[ 1]=-0.2970 θ[ 2]= 8.8745 θ[ 3]=-2.3873
#      θ[ 4]= 4.4914 θ[ 5]=-0.2970 θ[ 6]=-6.7843 θ[ 7]= 3.5658
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 18
# ============================================================
# 📊 Energy = -29.47574313 Hartree
# 📊 Energy = -18496.2941 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 4.92178868 Hartree
# 📈 Energy improvement: -1.48544953 Hartree (-932.1329 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.5339,  8.6242]
#    Parameter variance: 17.9579
#    RMS parameter:  4.8273
#    Parameters:
#      θ[ 0]= 6.5339 θ[ 1]=-0.0467 θ[ 2]= 8.6242 θ[ 3]=-2.1369
#      θ[ 4]= 4.2410 θ[ 5]=-0.0467 θ[ 6]=-6.5339 θ[ 7]= 3.3155
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 19
# ============================================================
# 📊 Energy = -34.88216603 Hartree
# 📊 Energy = -21888.8731 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -0.48463422 Hartree
# 📈 Energy improvement: 5.40642290 Hartree (3392.5790 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.1635,  9.2538]
#    Parameter variance: 22.0906
#    RMS parameter:  5.3339
#    Parameters:
#      θ[ 0]= 7.1635 θ[ 1]=-0.6763 θ[ 2]= 9.2538 θ[ 3]=-2.7665
#      θ[ 4]= 4.8707 θ[ 5]=-0.6763 θ[ 6]=-7.1635 θ[ 7]= 3.9451
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  6 energy=-34.88216603 ΔE=4.777e+00 ak=8.501e-02 ck=1.252e-01
#
# ============================================================
# 🔄 VQE ITERATION 20
# ============================================================
# 📊 Energy = -35.33598981 Hartree
# 📊 Energy = -22173.6516 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -0.93845800 Hartree
# 📈 Energy improvement: 0.45382378 Hartree (284.7785 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.2868,  9.3770]
#    Parameter variance: 22.5647
#    RMS parameter:  5.3878
#    Parameters:
#      θ[ 0]= 7.0403 θ[ 1]=-0.7995 θ[ 2]= 9.3770 θ[ 3]=-2.8898
#      θ[ 4]= 4.7474 θ[ 5]=-0.5530 θ[ 6]=-7.2868 θ[ 7]= 4.0683
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 21
# ============================================================
# 📊 Energy = -34.71820779 Hartree
# 📊 Energy = -21785.9879 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -0.32067597 Hartree
# 📈 Energy improvement: -0.61778203 Hartree (-387.6638 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.0403,  9.1306]
#    Parameter variance: 21.6460
#    RMS parameter:  5.2823
#    Parameters:
#      θ[ 0]= 7.2868 θ[ 1]=-0.5530 θ[ 2]= 9.1306 θ[ 3]=-2.6433
#      θ[ 4]= 4.9939 θ[ 5]=-0.7995 θ[ 6]=-7.0403 θ[ 7]= 3.8218
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 22
# ============================================================
# 📊 Energy = -35.65688953 Hartree
# 📊 Energy = -22375.0191 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -1.25935772 Hartree
# 📈 Energy improvement: 0.93868175 Hartree (589.0312 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.3578,  9.4480]
#    Parameter variance: 22.8511
#    RMS parameter:  5.4199
#    Parameters:
#      θ[ 0]= 6.9693 θ[ 1]=-0.8705 θ[ 2]= 9.4480 θ[ 3]=-2.9607
#      θ[ 4]= 4.6765 θ[ 5]=-0.4821 θ[ 6]=-7.3578 θ[ 7]= 4.1393
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  7 energy=-35.65688953 ΔE=7.747e-01 ak=7.748e-02 ck=1.232e-01
#
# ============================================================
# 🔄 VQE ITERATION 23
# ============================================================
# 📊 Energy = -37.63844702 Hartree
# 📊 Energy = -23618.4643 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -3.24091521 Hartree
# 📈 Energy improvement: 1.98155749 Hartree (1243.4452 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.4793,  9.5696]
#    Parameter variance: 23.6099
#    RMS parameter:  5.4989
#    Parameters:
#      θ[ 0]= 7.0909 θ[ 1]=-0.9921 θ[ 2]= 9.5696 θ[ 3]=-3.0823
#      θ[ 4]= 4.7980 θ[ 5]=-0.3605 θ[ 6]=-7.4793 θ[ 7]= 4.2609
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 24
# ============================================================
# 📊 Energy = -34.22064504 Hartree
# 📊 Energy = -21473.7627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 0.17688677 Hartree
# 📈 Energy improvement: -3.41780198 Hartree (-2144.7015 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.2362,  9.3264]
#    Parameter variance: 22.1210
#    RMS parameter:  5.3425
#    Parameters:
#      θ[ 0]= 6.8478 θ[ 1]=-0.7489 θ[ 2]= 9.3264 θ[ 3]=-2.8392
#      θ[ 4]= 4.5549 θ[ 5]=-0.6037 θ[ 6]=-7.2362 θ[ 7]= 4.0177
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 25
# ============================================================
# 📊 Energy = -42.40702612 Hartree
# 📊 Energy = -26610.7906 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.00949430 Hartree
# 📈 Energy improvement: 8.18638107 Hartree (5137.0278 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.3626, 10.4529]
#    Parameter variance: 29.9856
#    RMS parameter:  6.1150
#    Parameters:
#      θ[ 0]= 7.9742 θ[ 1]=-1.8754 θ[ 2]=10.4529 θ[ 3]=-3.9656
#      θ[ 4]= 5.6814 θ[ 5]= 0.5228 θ[ 6]=-8.3626 θ[ 7]= 5.1442
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  8 energy=-42.40702612 ΔE=6.750e+00 ak=7.150e-02 ck=1.216e-01
#
# ============================================================
# 🔄 VQE ITERATION 26
# ============================================================
# 📊 Energy = -41.96656421 Hartree
# 📊 Energy = -26334.3967 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.56903240 Hartree
# 📈 Energy improvement: -0.44046190 Hartree (-276.3938 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4828, 10.3328]
#    Parameter variance: 30.2006
#    RMS parameter:  6.1326
#    Parameters:
#      θ[ 0]= 7.8541 θ[ 1]=-1.9955 θ[ 2]=10.3328 θ[ 3]=-3.8455
#      θ[ 4]= 5.8015 θ[ 5]= 0.6430 θ[ 6]=-8.4828 θ[ 7]= 5.2643
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 27
# ============================================================
# 📊 Energy = -43.14065485 Hartree
# 📊 Energy = -27071.1492 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.74312304 Hartree
# 📈 Energy improvement: 1.17409064 Hartree (736.7524 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2425, 10.5730]
#    Parameter variance: 29.7994
#    RMS parameter:  6.0998
#    Parameters:
#      θ[ 0]= 8.0944 θ[ 1]=-1.7552 θ[ 2]=10.5730 θ[ 3]=-4.0858
#      θ[ 4]= 5.5612 θ[ 5]= 0.4027 θ[ 6]=-8.2425 θ[ 7]= 5.0240
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 28
# ============================================================
# 📊 Energy = -44.65893309 Hartree
# 📊 Energy = -28023.8824 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.26140128 Hartree
# 📈 Energy improvement: 1.51827823 Hartree (952.7333 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.0372, 10.7783]
#    Parameter variance: 29.5482
#    RMS parameter:  6.0791
#    Parameters:
#      θ[ 0]= 8.2996 θ[ 1]=-1.5499 θ[ 2]=10.7783 θ[ 3]=-4.2911
#      θ[ 4]= 5.3559 θ[ 5]= 0.1974 θ[ 6]=-8.0372 θ[ 7]= 4.8188
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  9 energy=-44.65893309 ΔE=2.252e+00 ak=6.660e-02 ck=1.201e-01
#
# ============================================================
# 🔄 VQE ITERATION 29
# ============================================================
# 📊 Energy = -41.87429594 Hartree
# 📊 Energy = -26276.4976 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.47676413 Hartree
# 📈 Energy improvement: -2.78463715 Hartree (-1747.3849 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.1561, 10.8972]
#    Parameter variance: 29.6104
#    RMS parameter:  6.0754
#    Parameters:
#      θ[ 0]= 8.4185 θ[ 1]=-1.6688 θ[ 2]=10.8972 θ[ 3]=-4.1722
#      θ[ 4]= 5.2371 θ[ 5]= 0.3163 θ[ 6]=-8.1561 θ[ 7]= 4.6999
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 30
# ============================================================
# 📊 Energy = -46.73729699 Hartree
# 📊 Energy = -29328.0745 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -12.33976518 Hartree
# 📈 Energy improvement: 4.86300105 Hartree (3051.5769 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.9183, 10.6594]
#    Parameter variance: 29.5135
#    RMS parameter:  6.0852
#    Parameters:
#      θ[ 0]= 8.1808 θ[ 1]=-1.4311 θ[ 2]=10.6594 θ[ 3]=-4.4099
#      θ[ 4]= 5.4748 θ[ 5]= 0.0785 θ[ 6]=-7.9183 θ[ 7]= 4.9376
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 31
# ============================================================
# 📊 Energy = -25.87540728 Hartree
# 📊 Energy = -16237.0509 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 8.52212453 Hartree
# 📈 Energy improvement: -20.86188971 Hartree (-13091.0236 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.7587, 10.8489]
#    Parameter variance: 30.6163
#    RMS parameter:  6.2633
#    Parameters:
#      θ[ 0]= 7.0211 θ[ 1]=-0.2714 θ[ 2]= 9.4998 θ[ 3]=-5.5696
#      θ[ 4]= 6.6345 θ[ 5]=-1.0812 θ[ 6]=-6.7587 θ[ 7]= 6.0973
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 10 energy=-25.87540728 ΔE=-1.878e+01 ak=6.251e-02 ck=1.189e-01
#
# ============================================================
# 🔄 VQE ITERATION 32
# ============================================================
# 📊 Energy = -26.23553830 Hartree
# 📊 Energy = -16463.0364 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 8.16199352 Hartree
# 📈 Energy improvement: 0.36013102 Hartree (225.9855 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.8764, 10.9666]
#    Parameter variance: 31.1279
#    RMS parameter:  6.3040
#    Parameters:
#      θ[ 0]= 6.9033 θ[ 1]=-0.1536 θ[ 2]= 9.6175 θ[ 3]=-5.6874
#      θ[ 4]= 6.7522 θ[ 5]=-1.1989 θ[ 6]=-6.8764 θ[ 7]= 5.9796
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 33
# ============================================================
# 📊 Energy = -26.00919158 Hartree
# 📊 Energy = -16321.0018 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 8.38834023 Hartree
# 📈 Energy improvement: -0.22634672 Hartree (-142.0346 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.6409, 10.7311]
#    Parameter variance: 30.1323
#    RMS parameter:  6.2246
#    Parameters:
#      θ[ 0]= 7.1388 θ[ 1]=-0.3891 θ[ 2]= 9.3820 θ[ 3]=-5.4519
#      θ[ 4]= 6.5168 θ[ 5]=-0.9634 θ[ 6]=-6.6409 θ[ 7]= 6.2151
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 34
# ============================================================
# 📊 Energy = -25.99333557 Hartree
# 📊 Energy = -16311.0520 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 8.40419624 Hartree
# 📈 Energy improvement: -0.01585600 Hartree (-9.9498 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.8154, 10.9056]
#    Parameter variance: 30.8594
#    RMS parameter:  6.2827
#    Parameters:
#      θ[ 0]= 6.9643 θ[ 1]=-0.2146 θ[ 2]= 9.5565 θ[ 3]=-5.6264
#      θ[ 4]= 6.6912 θ[ 5]=-1.1379 θ[ 6]=-6.8154 θ[ 7]= 6.0406
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 11 energy=-25.99333557 ΔE=1.179e-01 ak=5.902e-02 ck=1.177e-01
#
# ============================================================
# 🔄 VQE ITERATION 35
# ============================================================
# 📊 Energy = -26.69064895 Hartree
# 📊 Energy = -16748.6224 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 7.70688287 Hartree
# 📈 Energy improvement: 0.69731337 Hartree (437.5704 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.9321, 10.7889]
#    Parameter variance: 30.6531
#    RMS parameter:  6.2572
#    Parameters:
#      θ[ 0]= 6.8476 θ[ 1]=-0.0979 θ[ 2]= 9.6732 θ[ 3]=-5.5096
#      θ[ 4]= 6.8079 θ[ 5]=-1.2546 θ[ 6]=-6.9321 θ[ 7]= 5.9239
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 36
# ============================================================
# 📊 Energy = -25.09355170 Hartree
# 📊 Energy = -15746.4295 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 9.30398011 Hartree
# 📈 Energy improvement: -1.59709725 Hartree (-1002.1929 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.6987, 11.0223]
#    Parameter variance: 31.0921
#    RMS parameter:  6.3103
#    Parameters:
#      θ[ 0]= 7.0811 θ[ 1]=-0.3314 θ[ 2]= 9.4398 θ[ 3]=-5.7431
#      θ[ 4]= 6.5745 θ[ 5]=-1.0212 θ[ 6]=-6.6987 θ[ 7]= 6.1573
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 37
# ============================================================
# 📊 Energy = -27.21006444 Hartree
# 📊 Energy = -17074.5603 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 7.18746737 Hartree
# 📈 Energy improvement: 2.11651275 Hartree (1328.1308 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.1986, 10.5224]
#    Parameter variance: 30.2814
#    RMS parameter:  6.2067
#    Parameters:
#      θ[ 0]= 6.5811 θ[ 1]= 0.1686 θ[ 2]= 9.9397 θ[ 3]=-5.2431
#      θ[ 4]= 7.0745 θ[ 5]=-1.5212 θ[ 6]=-7.1986 θ[ 7]= 5.6573
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 12 energy=-27.21006444 ΔE=1.217e+00 ak=5.601e-02 ck=1.167e-01
#
# ============================================================
# 🔄 VQE ITERATION 38
# ============================================================
# 📊 Energy = -27.87256141 Hartree
# 📊 Energy = -17490.2831 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 6.52497040 Hartree
# 📈 Energy improvement: 0.66249697 Hartree (415.7228 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.0829, 10.6381]
#    Parameter variance: 30.7818
#    RMS parameter:  6.2648
#    Parameters:
#      θ[ 0]= 6.4653 θ[ 1]= 0.2844 θ[ 2]=10.0555 θ[ 3]=-5.3589
#      θ[ 4]= 7.1902 θ[ 5]=-1.6369 θ[ 6]=-7.0829 θ[ 7]= 5.7731
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 39
# ============================================================
# 📊 Energy = -27.24060660 Hartree
# 📊 Energy = -17093.7258 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 7.15692521 Hartree
# 📈 Energy improvement: -0.63195481 Hartree (-396.5573 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.3144, 10.4066]
#    Parameter variance: 29.8049
#    RMS parameter:  6.1504
#    Parameters:
#      θ[ 0]= 6.6969 θ[ 1]= 0.0528 θ[ 2]= 9.8240 θ[ 3]=-5.1273
#      θ[ 4]= 6.9587 θ[ 5]=-1.4054 θ[ 6]=-7.3144 θ[ 7]= 5.5416
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 40
# ============================================================
# 📊 Energy = -28.09665139 Hartree
# 📊 Energy = -17630.9016 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 6.30088042 Hartree
# 📈 Energy improvement: 0.85604479 Hartree (537.1758 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.0529, 10.6681]
#    Parameter variance: 30.9150
#    RMS parameter:  6.2800
#    Parameters:
#      θ[ 0]= 6.4354 θ[ 1]= 0.3143 θ[ 2]=10.0854 θ[ 3]=-5.3888
#      θ[ 4]= 7.2202 θ[ 5]=-1.6668 θ[ 6]=-7.0529 θ[ 7]= 5.8030
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 13 energy=-28.09665139 ΔE=8.866e-01 ak=5.338e-02 ck=1.158e-01
#
# ============================================================
# 🔄 VQE ITERATION 41
# ============================================================
# 📊 Energy = -28.71339465 Hartree
# 📊 Energy = -18017.9136 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 5.68413716 Hartree
# 📈 Energy improvement: 0.61674327 Hartree (387.0119 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.1679, 10.7830]
#    Parameter variance: 31.2248
#    RMS parameter:  6.3224
#    Parameters:
#      θ[ 0]= 6.5503 θ[ 1]= 0.1994 θ[ 2]=10.2003 θ[ 3]=-5.2739
#      θ[ 4]= 7.3351 θ[ 5]=-1.5519 θ[ 6]=-7.1679 θ[ 7]= 5.6881
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 42
# ============================================================
# 📊 Energy = -27.52686570 Hartree
# 📊 Energy = -17273.3560 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 6.87066611 Hartree
# 📈 Energy improvement: -1.18652895 Hartree (-744.5576 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-6.9380, 10.5531]
#    Parameter variance: 30.6287
#    RMS parameter:  6.2394
#    Parameters:
#      θ[ 0]= 6.3205 θ[ 1]= 0.4292 θ[ 2]= 9.9705 θ[ 3]=-5.5037
#      θ[ 4]= 7.1053 θ[ 5]=-1.7817 θ[ 6]=-6.9380 θ[ 7]= 5.9179
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 43
# ============================================================
# 📊 Energy = -29.53781216 Hartree
# 📊 Energy = -18535.2430 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 4.85971965 Hartree
# 📈 Energy improvement: 2.01094646 Hartree (1261.8870 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.3165, 10.9316]
#    Parameter variance: 31.6604
#    RMS parameter:  6.3800
#    Parameters:
#      θ[ 0]= 6.6990 θ[ 1]= 0.0507 θ[ 2]=10.3490 θ[ 3]=-5.1252
#      θ[ 4]= 7.4837 θ[ 5]=-1.4033 θ[ 6]=-7.3165 θ[ 7]= 5.5395
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 14 energy=-29.53781216 ΔE=1.441e+00 ak=5.105e-02 ck=1.149e-01
#
# ============================================================
# 🔄 VQE ITERATION 44
# ============================================================
# 📊 Energy = -28.02234089 Hartree
# 📊 Energy = -17584.2711 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 6.37519092 Hartree
# 📈 Energy improvement: -1.51547127 Hartree (-950.9719 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.2024, 11.0457]
#    Parameter variance: 31.8806
#    RMS parameter:  6.4334
#    Parameters:
#      θ[ 0]= 6.8131 θ[ 1]= 0.1648 θ[ 2]=10.4631 θ[ 3]=-5.2393
#      θ[ 4]= 7.5978 θ[ 5]=-1.2892 θ[ 6]=-7.2024 θ[ 7]= 5.4254
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 45
# ============================================================
# 📊 Energy = -30.74656627 Hartree
# 📊 Energy = -19293.7471 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 3.65096554 Hartree
# 📈 Energy improvement: 2.72422537 Hartree (1709.4759 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.4306, 10.8175]
#    Parameter variance: 31.4546
#    RMS parameter:  6.3283
#    Parameters:
#      θ[ 0]= 6.5849 θ[ 1]=-0.0634 θ[ 2]=10.2349 θ[ 3]=-5.0111
#      θ[ 4]= 7.3696 θ[ 5]=-1.5174 θ[ 6]=-7.4306 θ[ 7]= 5.6536
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 46
# ============================================================
# 📊 Energy = -33.40749074 Hartree
# 📊 Energy = -20963.5011 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 0.99004107 Hartree
# 📈 Energy improvement: 2.66092447 Hartree (1669.7541 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.9011, 10.3470]
#    Parameter variance: 30.7589
#    RMS parameter:  6.1328
#    Parameters:
#      θ[ 0]= 6.1144 θ[ 1]=-0.5339 θ[ 2]= 9.7644 θ[ 3]=-4.5407
#      θ[ 4]= 6.8992 θ[ 5]=-1.9879 θ[ 6]=-7.9011 θ[ 7]= 6.1240
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 15 energy=-33.40749074 ΔE=3.870e+00 ak=4.897e-02 ck=1.141e-01
#
# ============================================================
# 🔄 VQE ITERATION 47
# ============================================================
# 📊 Energy = -34.90263985 Hartree
# 📊 Energy = -21901.7206 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -0.50510804 Hartree
# 📈 Energy improvement: 1.49514911 Hartree (938.2195 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.0145, 10.4604]
#    Parameter variance: 31.0165
#    RMS parameter:  6.1298
#    Parameters:
#      θ[ 0]= 6.0010 θ[ 1]=-0.4205 θ[ 2]= 9.6511 θ[ 3]=-4.6540
#      θ[ 4]= 6.7858 θ[ 5]=-2.1012 θ[ 6]=-8.0145 θ[ 7]= 6.0107
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 48
# ============================================================
# 📊 Energy = -32.60134801 Hartree
# 📊 Energy = -20457.6393 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 1.79618380 Hartree
# 📈 Energy improvement: -2.30129184 Hartree (-1444.0813 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.7877, 10.2337]
#    Parameter variance: 30.5207
#    RMS parameter:  6.1378
#    Parameters:
#      θ[ 0]= 6.2278 θ[ 1]=-0.6472 θ[ 2]= 9.8778 θ[ 3]=-4.4273
#      θ[ 4]= 7.0125 θ[ 5]=-1.8745 θ[ 6]=-7.7877 θ[ 7]= 6.2374
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 49
# ============================================================
# 📊 Energy = -40.18869493 Hartree
# 📊 Energy = -25218.7678 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.79116311 Hartree
# 📈 Energy improvement: 7.58734691 Hartree (4761.1285 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.3792, 10.8252]
#    Parameter variance: 31.9758
#    RMS parameter:  6.1346
#    Parameters:
#      θ[ 0]= 5.6363 θ[ 1]=-0.0557 θ[ 2]= 9.2863 θ[ 3]=-5.0188
#      θ[ 4]= 6.4210 θ[ 5]=-2.4660 θ[ 6]=-8.3792 θ[ 7]= 5.6459
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 16 energy=-40.18869493 ΔE=6.781e+00 ak=4.710e-02 ck=1.134e-01
#
# ============================================================
# 🔄 VQE ITERATION 50
# ============================================================
# 📊 Energy = -38.85420289 Hartree
# 📊 Energy = -24381.3620 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.45667108 Hartree
# 📈 Energy improvement: -1.33449203 Hartree (-837.4058 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2665, 10.9378]
#    Parameter variance: 32.1360
#    RMS parameter:  6.1697
#    Parameters:
#      θ[ 0]= 5.7490 θ[ 1]=-0.1684 θ[ 2]= 9.3990 θ[ 3]=-4.9061
#      θ[ 4]= 6.5337 θ[ 5]=-2.5786 θ[ 6]=-8.2665 θ[ 7]= 5.5333
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 51
# ============================================================
# 📊 Energy = -41.19319070 Hartree
# 📊 Energy = -25849.0979 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.79565888 Hartree
# 📈 Energy improvement: 2.33898780 Hartree (1467.7359 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4919, 10.7125]
#    Parameter variance: 31.8347
#    RMS parameter:  6.1014
#    Parameters:
#      θ[ 0]= 5.5236 θ[ 1]= 0.0569 θ[ 2]= 9.1736 θ[ 3]=-5.1314
#      θ[ 4]= 6.3084 θ[ 5]=-2.3533 θ[ 6]=-8.4919 θ[ 7]= 5.7586
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 52
# ============================================================
# 📊 Energy = -43.14354641 Hartree
# 📊 Energy = -27072.9637 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.74601460 Hartree
# 📈 Energy improvement: 1.95035572 Hartree (1223.8658 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.8506, 10.3537]
#    Parameter variance: 31.5122
#    RMS parameter:  6.0087
#    Parameters:
#      θ[ 0]= 5.1649 θ[ 1]= 0.4157 θ[ 2]= 8.8149 θ[ 3]=-5.4902
#      θ[ 4]= 5.9496 θ[ 5]=-1.9946 θ[ 6]=-8.8506 θ[ 7]= 6.1173
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 17 energy=-43.14354641 ΔE=2.955e+00 ak=4.542e-02 ck=1.127e-01
#
# ============================================================
# 🔄 VQE ITERATION 53
# ============================================================
# 📊 Energy = -42.25673477 Hartree
# 📊 Energy = -26516.4814 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.85920295 Hartree
# 📈 Energy improvement: -0.88681165 Hartree (-556.4823 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.9626, 10.4658]
#    Parameter variance: 31.4083
#    RMS parameter:  5.9868
#    Parameters:
#      θ[ 0]= 5.0529 θ[ 1]= 0.3036 θ[ 2]= 8.7029 θ[ 3]=-5.3781
#      θ[ 4]= 5.8376 θ[ 5]=-2.1066 θ[ 6]=-8.9626 θ[ 7]= 6.0053
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 54
# ============================================================
# 📊 Energy = -43.78820525 Hartree
# 📊 Energy = -27477.4929 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -9.39067343 Hartree
# 📈 Energy improvement: 1.53147048 Hartree (961.0115 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.7386, 10.2417]
#    Parameter variance: 31.6383
#    RMS parameter:  6.0326
#    Parameters:
#      θ[ 0]= 5.2769 θ[ 1]= 0.5277 θ[ 2]= 8.9269 θ[ 3]=-5.6022
#      θ[ 4]= 6.0617 θ[ 5]=-1.8825 θ[ 6]=-8.7386 θ[ 7]= 6.2294
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 55
# ============================================================
# 📊 Energy = -44.45442515 Hartree
# 📊 Energy = -27895.5519 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.05689334 Hartree
# 📈 Energy improvement: 0.66621990 Hartree (418.0590 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.5507, 10.0538]
#    Parameter variance: 31.9001
#    RMS parameter:  6.0771
#    Parameters:
#      θ[ 0]= 5.4648 θ[ 1]= 0.7156 θ[ 2]= 9.1148 θ[ 3]=-5.7901
#      θ[ 4]= 6.2496 θ[ 5]=-1.6946 θ[ 6]=-8.5507 θ[ 7]= 6.4173
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 18 energy=-44.45442515 ΔE=1.311e+00 ak=4.388e-02 ck=1.120e-01
#
# ============================================================
# 🔄 VQE ITERATION 56
# ============================================================
# 📊 Energy = -43.86179512 Hartree
# 📊 Energy = -27523.6712 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -9.46426330 Hartree
# 📈 Energy improvement: -0.59263003 Hartree (-371.8807 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4392,  9.9424]
#    Parameter variance: 31.5624
#    RMS parameter:  6.0423
#    Parameters:
#      θ[ 0]= 5.3534 θ[ 1]= 0.8270 θ[ 2]= 9.0034 θ[ 3]=-5.9015
#      θ[ 4]= 6.1382 θ[ 5]=-1.5832 θ[ 6]=-8.4392 θ[ 7]= 6.5287
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 57
# ============================================================
# 📊 Energy = -45.57014143 Hartree
# 📊 Energy = -28595.6739 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -11.17260962 Hartree
# 📈 Energy improvement: 1.70834632 Hartree (1072.0027 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6621, 10.1652]
#    Parameter variance: 32.2621
#    RMS parameter:  6.1136
#    Parameters:
#      θ[ 0]= 5.5762 θ[ 1]= 0.6042 θ[ 2]= 9.2263 θ[ 3]=-5.6787
#      θ[ 4]= 6.3610 θ[ 5]=-1.8060 θ[ 6]=-8.6621 θ[ 7]= 6.3059
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 58
# ============================================================
# 📊 Energy = -48.94085096 Hartree
# 📊 Energy = -30710.8244 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.54331914 Hartree
# 📈 Energy improvement: 3.37070952 Hartree (2115.1506 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.8763, 10.3794]
#    Parameter variance: 33.0258
#    RMS parameter:  6.1889
#    Parameters:
#      θ[ 0]= 5.7905 θ[ 1]= 0.3900 θ[ 2]= 9.4405 θ[ 3]=-5.4645
#      θ[ 4]= 6.5752 θ[ 5]=-2.0203 θ[ 6]=-8.8763 θ[ 7]= 6.0916
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 19 energy=-48.94085096 ΔE=4.486e+00 ak=4.247e-02 ck=1.114e-01
#
# ============================================================
# 🔄 VQE ITERATION 59
# ============================================================
# 📊 Energy = -48.82586151 Hartree
# 📊 Energy = -30638.6675 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.42832969 Hartree
# 📈 Energy improvement: -0.11498945 Hartree (-72.1569 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.9871, 10.4903]
#    Parameter variance: 33.3143
#    RMS parameter:  6.2259
#    Parameters:
#      θ[ 0]= 5.9013 θ[ 1]= 0.5008 θ[ 2]= 9.3296 θ[ 3]=-5.5753
#      θ[ 4]= 6.4644 θ[ 5]=-1.9094 θ[ 6]=-8.9871 θ[ 7]= 6.2025
#      ... and 4 more parameters
#    ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-57572204.py in <cell line: 0>()
#      34 vqe_simple = VQE(generic, DirectHam(ham_system), basic_optimizer, no_zne, verbose=True, estimator=estimator)
#      35 init_simple = generic.get_initial_parameters('zero')
# ---> 36 params_simple, energy_simple = vqe_simple.run(init_simple)
#      37
#      38 shift = getattr(vqe_simple, 'energy_constant_shift', 0.0) or 0.0
#
# /content/GroundStateFinder/vqeskeletal.py in run(self, initial_params, init_type)
#    1427
#    1428         # Run optimizer
# -> 1429         best_params = self.optimizer_plugin.optimize(self.objective_function, initial_params)
#    1430
#    1431         # Ensure we have energy for returned params (optimizer may store best earlier)
#
# /content/GroundStateFinder/vqeskeletal.py in optimize(self, objective_function, initial_params)
#     923             minus = params - ck * delta
#     924             e_plus = objective_function(plus)
# --> 925             e_minus = objective_function(minus)
#     926             # Gradient estimate (vector)
#     927             gk = (e_plus - e_minus) / (2.0 * ck) * delta
#
# /content/GroundStateFinder/vqeskeletal.py in objective_function(self, parameters)
#    1312         else:
#    1313             # Single-factor (legacy) path
# -> 1314             single_val = self._simulate_measurement(trial_wavefunction, hamiltonian)
#    1315             try:
#    1316                 single_val = float(single_val)
#
# /content/GroundStateFinder/vqeskeletal.py in _simulate_measurement(self, trial_wavefunction, hamiltonian)
#    1191             except TypeError:
#    1192                 job = self.estimator.run([(trial_wavefunction, hamiltonian)])
# -> 1193             estimator_result = job.result()
#    1194
#    1195             def collect_numbers(obj, depth=0, found=None):
#
# /usr/local/lib/python3.12/dist-packages/qiskit/primitives/primitive_job.py in result(self)
#      63         if self._result is None:
#      64             self._check_submitted()
# ---> 65             self._result = self._future.result()
#      66         return self._result
#      67
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Cell 5 Description: Simple VQE (Hardware-Efficient Ansatz, With Noise)
#
# Runs a standalone SPSA optimization on a small hardware‑efficient (Ry+CX) ansatz built directly from the NH3 Hamiltonian qubit count. This is a neutral baseline with zero or random initialization and no chemistry priors. Simulates depolarizing noise on all gates. ZNE is not used here.

# %%
# === 5. Basic VQE (SPSA only, no ZNE) — Generic hardware-efficient ansatz ===
from vqeskeletal import VQE, ZNEDenoiserPlugin, SPSAOptimizer, GenericAnsatzPlugin

class DirectHam:
    def __init__(self, sysd): self.sysd = sysd
    def get_hamiltonian(self): return self.sysd

# Build a small HEA baseline (no chemistry priors)
# Note: params = layers * num_qubits; with 6 qubits and layers=2 -> 12 parameters.
# To try fewer params, use layers=1 (-> 6 params).
generic = GenericAnsatzPlugin(layers=2, entanglement='linear', verbose=True)
generic.build_from_hamiltonian(ham_system)
print(f"[Basic] HEA ansatz: qubits={generic.num_qubits}, params={generic.num_parameters}, layers={generic.layers}")

# Increase SPSA iterations to 200
BASIC_SPSA_ITERS = 200
basic_optimizer = SPSAOptimizer(max_iter=BASIC_SPSA_ITERS, a=0.25, c=0.15, tol=5e-4, verbose=True)
print(f"[Basic] SPSA iterations set to {BASIC_SPSA_ITERS} (expected objective evals ≈ {3*BASIC_SPSA_ITERS + 2})")

no_zne = ZNEDenoiserPlugin(noise_factors=[1.0], extrapolation_method='linear', verbose=False)

vqe_basic = VQE(generic, DirectHam(ham_system), basic_optimizer, no_zne, verbose=True)
# Choose standard "normal VQE" starts: zero or random
init_basic = generic.get_initial_parameters('zero')  # or 'random_normal'
params_basic, energy_basic = vqe_basic.run(init_basic)

# Report both raw and shift-adjusted energies for clarity
shift = getattr(vqe_basic, 'energy_constant_shift', 0.0) or 0.0
print('\n[Basic VQE] Final total energy (raw):', f'{energy_basic:.10f} Hartree')
print('[Basic VQE] Final energy (minus constant shift', f'{shift:.6f}', '):', f'{(energy_basic-shift):.10f} Hartree')

# Expose for summary table
energy_basic = float(energy_basic)
# Out:
# ✓ Generic ansatz built (layers=2, entanglement=linear, params=12)
# [Basic] HEA ansatz: qubits=6, params=12, layers=2
# [Basic] SPSA iterations set to 200 (expected objective evals ≈ 602)
# 🔄 Initializing VQE system...
# ✓ Generic ansatz built (layers=2, entanglement=linear, params=12)
# ✓ Quantum estimator setup complete (Qiskit Aer)
#
# 🚀 Starting VQE optimization run
#    Parameter count: 12
#    Optimizer: SPSAOptimizer
#
# ============================================================
# 🔄 VQE ITERATION 1
# ============================================================
# 📊 Energy = -0.00000000 Hartree
# 📊 Energy = -0.0000 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 34.39753181 Hartree
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [ 0.0000,  0.0000]
#    Parameter variance:  0.0000
#    RMS parameter:  0.0000
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#      ... and 4 more parameters
#    ==================================================
# [SPSA] Initial energy: -4.440892098500626e-15
#
# ============================================================
# 🔄 VQE ITERATION 2
# ============================================================
# 📊 Energy = -1.75468950 Hartree
# 📊 Energy = -1101.0835 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 32.64284232 Hartree
# 📈 Energy improvement: 1.75468950 Hartree (1101.0835 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.1500,  0.1500]
#    Parameter variance:  0.0200
#    RMS parameter:  0.1500
#    Parameters:
#      θ[ 0]= 0.1500 θ[ 1]=-0.1500 θ[ 2]= 0.1500 θ[ 3]= 0.1500
#      θ[ 4]= 0.1500 θ[ 5]= 0.1500 θ[ 6]=-0.1500 θ[ 7]= 0.1500
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 3
# ============================================================
# 📊 Energy = -1.88413157 Hartree
# 📊 Energy = -1182.3095 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 32.51340024 Hartree
# 📈 Energy improvement: 0.12944208 Hartree (81.2261 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.1500,  0.1500]
#    Parameter variance:  0.0200
#    RMS parameter:  0.1500
#    Parameters:
#      θ[ 0]=-0.1500 θ[ 1]= 0.1500 θ[ 2]=-0.1500 θ[ 3]=-0.1500
#      θ[ 4]=-0.1500 θ[ 5]=-0.1500 θ[ 6]= 0.1500 θ[ 7]=-0.1500
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 4
# ============================================================
# 📊 Energy = -0.98027191 Hartree
# 📊 Energy = -615.1294 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 33.41725990 Hartree
# 📈 Energy improvement: -0.90385966 Hartree (-567.1801 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.1079,  0.1079]
#    Parameter variance:  0.0103
#    RMS parameter:  0.1079
#    Parameters:
#      θ[ 0]=-0.1079 θ[ 1]= 0.1079 θ[ 2]=-0.1079 θ[ 3]=-0.1079
#      θ[ 4]=-0.1079 θ[ 5]=-0.1079 θ[ 6]= 0.1079 θ[ 7]=-0.1079
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  1 energy=-0.98027191 ΔE=9.803e-01 ak=2.500e-01 ck=1.500e-01
#
# ============================================================
# 🔄 VQE ITERATION 5
# ============================================================
# 📊 Energy = -2.53385594 Hartree
# 📊 Energy = -1590.0174 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 31.86367587 Hartree
# 📈 Energy improvement: 1.55358403 Hartree (974.8880 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.2477,  0.2477]
#    Parameter variance:  0.0299
#    RMS parameter:  0.1766
#    Parameters:
#      θ[ 0]= 0.0320 θ[ 1]=-0.0320 θ[ 2]=-0.2477 θ[ 3]= 0.0320
#      θ[ 4]= 0.0320 θ[ 5]=-0.2477 θ[ 6]= 0.2477 θ[ 7]=-0.2477
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 6
# ============================================================
# 📊 Energy = -2.48586762 Hartree
# 📊 Energy = -1559.9043 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 31.91166419 Hartree
# 📈 Energy improvement: -0.04798832 Hartree (-30.1131 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.2477,  0.2477]
#    Parameter variance:  0.0299
#    RMS parameter:  0.1766
#    Parameters:
#      θ[ 0]=-0.2477 θ[ 1]= 0.2477 θ[ 2]= 0.0320 θ[ 3]=-0.2477
#      θ[ 4]=-0.2477 θ[ 5]= 0.0320 θ[ 6]=-0.0320 θ[ 7]= 0.0320
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 7
# ============================================================
# 📊 Energy = -1.07584846 Hartree
# 📊 Energy = -675.1046 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 33.32168336 Hartree
# 📈 Energy improvement: -1.41001917 Hartree (-884.7997 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.1361,  0.1361]
#    Parameter variance:  0.0111
#    RMS parameter:  0.1115
#    Parameters:
#      θ[ 0]=-0.0796 θ[ 1]= 0.0796 θ[ 2]=-0.1361 θ[ 3]=-0.0796
#      θ[ 4]=-0.0796 θ[ 5]=-0.1361 θ[ 6]= 0.1361 θ[ 7]=-0.1361
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  2 energy=-1.07584846 ΔE=9.558e-02 ak=1.647e-01 ck=1.399e-01
#
# ============================================================
# 🔄 VQE ITERATION 8
# ============================================================
# 📊 Energy = -2.50437828 Hartree
# 📊 Energy = -1571.5199 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 31.89315353 Hartree
# 📈 Energy improvement: 1.42852982 Hartree (896.4153 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.2704,  0.2704]
#    Parameter variance:  0.0336
#    RMS parameter:  0.2003
#    Parameters:
#      θ[ 0]=-0.2139 θ[ 1]= 0.2139 θ[ 2]=-0.2704 θ[ 3]=-0.2139
#      θ[ 4]=-0.2139 θ[ 5]=-0.2704 θ[ 6]= 0.2704 θ[ 7]=-0.0019
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 9
# ============================================================
# 📊 Energy = -2.00597155 Hartree
# 📊 Energy = -1258.7652 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 32.39156026 Hartree
# 📈 Energy improvement: -0.49840673 Hartree (-312.7547 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.2704,  0.2704]
#    Parameter variance:  0.0207
#    RMS parameter:  0.1442
#    Parameters:
#      θ[ 0]= 0.0546 θ[ 1]=-0.0546 θ[ 2]=-0.0019 θ[ 3]= 0.0546
#      θ[ 4]= 0.0546 θ[ 5]=-0.0019 θ[ 6]= 0.0019 θ[ 7]=-0.2704
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 10
# ============================================================
# 📊 Energy = -4.54739831 Hartree
# 📊 Energy = -2853.5334 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 29.85013350 Hartree
# 📈 Energy improvement: 2.54142676 Hartree (1594.7682 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.3757,  0.3757]
#    Parameter variance:  0.0736
#    RMS parameter:  0.2950
#    Parameters:
#      θ[ 0]=-0.3191 θ[ 1]= 0.3191 θ[ 2]=-0.3757 θ[ 3]=-0.3191
#      θ[ 4]=-0.3191 θ[ 5]=-0.3757 θ[ 6]= 0.3757 θ[ 7]= 0.1034
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  3 energy=-4.54739831 ΔE=3.472e+00 ak=1.290e-01 ck=1.342e-01
#
# ============================================================
# 🔄 VQE ITERATION 11
# ============================================================
# 📊 Energy = -5.86738810 Hartree
# 📊 Energy = -3681.8388 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 28.53014372 Hartree
# 📈 Energy improvement: 1.31998978 Hartree (828.3055 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.5061,  0.5061]
#    Parameter variance:  0.1032
#    RMS parameter:  0.3226
#    Parameters:
#      θ[ 0]=-0.1887 θ[ 1]= 0.4495 θ[ 2]=-0.5061 θ[ 3]=-0.1887
#      θ[ 4]=-0.4495 θ[ 5]=-0.2453 θ[ 6]= 0.5061 θ[ 7]= 0.2338
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 12
# ============================================================
# 📊 Energy = -5.55395742 Hartree
# 📊 Energy = -3485.1583 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 28.84357439 Hartree
# 📈 Energy improvement: -0.31343067 Hartree (-196.6806 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.5061,  0.2453]
#    Parameter variance:  0.0629
#    RMS parameter:  0.3226
#    Parameters:
#      θ[ 0]=-0.4495 θ[ 1]= 0.1887 θ[ 2]=-0.2453 θ[ 3]=-0.4495
#      θ[ 4]=-0.1887 θ[ 5]=-0.5061 θ[ 6]= 0.2453 θ[ 7]=-0.0270
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 13
# ============================================================
# 📊 Energy = -5.86763272 Hartree
# 📊 Energy = -3681.9923 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 28.52989909 Hartree
# 📈 Energy improvement: 0.31367530 Hartree (196.8341 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.5061,  0.5061]
#    Parameter variance:  0.1032
#    RMS parameter:  0.3226
#    Parameters:
#      θ[ 0]=-0.1887 θ[ 1]= 0.4496 θ[ 2]=-0.5061 θ[ 3]=-0.1887
#      θ[ 4]=-0.4496 θ[ 5]=-0.2452 θ[ 6]= 0.5061 θ[ 7]= 0.2338
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  4 energy=-5.86763272 ΔE=1.320e+00 ak=1.085e-01 ck=1.304e-01
#
# ============================================================
# 🔄 VQE ITERATION 14
# ============================================================
# 📊 Energy = -5.30030931 Hartree
# 📊 Energy = -3325.9918 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 29.09722250 Hartree
# 📈 Energy improvement: -0.56732341 Hartree (-356.0005 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.3786,  0.5771]
#    Parameter variance:  0.0791
#    RMS parameter:  0.2835
#    Parameters:
#      θ[ 0]=-0.0612 θ[ 1]= 0.5771 θ[ 2]=-0.3786 θ[ 3]=-0.0612
#      θ[ 4]=-0.3221 θ[ 5]=-0.1177 θ[ 6]= 0.3786 θ[ 7]= 0.1063
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 15
# ============================================================
# 📊 Energy = -8.49613920 Hartree
# 📊 Energy = -5331.4038 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 25.90139261 Hartree
# 📈 Energy improvement: 3.19582989 Hartree (2005.4120 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-0.6336,  0.6336]
#    Parameter variance:  0.1517
#    RMS parameter:  0.4003
#    Parameters:
#      θ[ 0]=-0.3162 θ[ 1]= 0.3221 θ[ 2]=-0.6336 θ[ 3]=-0.3162
#      θ[ 4]=-0.5771 θ[ 5]=-0.3727 θ[ 6]= 0.6336 θ[ 7]= 0.3613
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 16
# ============================================================
# 📊 Energy = -50.77688958 Hartree
# 📊 Energy = -31862.9552 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.37935776 Hartree
# 📈 Energy improvement: 42.28075037 Hartree (26531.5514 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-1.6952,  1.6952]
#    Parameter variance:  1.5020
#    RMS parameter:  1.3750
#    Parameters:
#      θ[ 0]=-1.3778 θ[ 1]=-0.7395 θ[ 2]=-1.6952 θ[ 3]=-1.3778
#      θ[ 4]=-1.6387 θ[ 5]=-1.4343 θ[ 6]= 1.6952 θ[ 7]= 1.4229
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  5 energy=-50.77688958 ΔE=4.491e+01 ak=9.488e-02 ck=1.275e-01
#
# ============================================================
# 🔄 VQE ITERATION 17
# ============================================================
# 📊 Energy = -51.03025775 Hartree
# 📊 Energy = -32021.9460 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.63272594 Hartree
# 📈 Energy improvement: 0.25336817 Hartree (158.9908 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-1.8203,  1.8203]
#    Parameter variance:  1.7178
#    RMS parameter:  1.4514
#    Parameters:
#      θ[ 0]=-1.5030 θ[ 1]=-0.6144 θ[ 2]=-1.8203 θ[ 3]=-1.5030
#      θ[ 4]=-1.5135 θ[ 5]=-1.5595 θ[ 6]= 1.8203 θ[ 7]= 1.5481
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 18
# ============================================================
# 📊 Energy = -48.98234389 Hartree
# 📊 Energy = -30736.8616 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.58481208 Hartree
# 📈 Energy improvement: -2.04791386 Hartree (-1285.0844 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-1.7638,  1.5700]
#    Parameter variance:  1.3175
#    RMS parameter:  1.3062
#    Parameters:
#      θ[ 0]=-1.2527 θ[ 1]=-0.8647 θ[ 2]=-1.5700 θ[ 3]=-1.2527
#      θ[ 4]=-1.7638 θ[ 5]=-1.3092 θ[ 6]= 1.5700 θ[ 7]= 1.2978
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 19
# ============================================================
# 📊 Energy = -38.83734267 Hartree
# 📊 Energy = -24370.7821 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.43981086 Hartree
# 📈 Energy improvement: -10.14500123 Hartree (-6366.0796 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.3906,  2.3906]
#    Parameter variance:  3.0979
#    RMS parameter:  1.8672
#    Parameters:
#      θ[ 0]=-2.0733 θ[ 1]=-0.0441 θ[ 2]=-2.3906 θ[ 3]=-2.0733
#      θ[ 4]=-0.9432 θ[ 5]=-2.1298 θ[ 6]= 2.3906 θ[ 7]= 2.1184
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  6 energy=-38.83734267 ΔE=-1.194e+01 ak=8.501e-02 ck=1.252e-01
#
# ============================================================
# 🔄 VQE ITERATION 20
# ============================================================
# 📊 Energy = -37.77745080 Hartree
# 📊 Energy = -23705.6904 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -3.37991898 Hartree
# 📈 Energy improvement: -1.05989187 Hartree (-665.0917 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.2674,  2.2674]
#    Parameter variance:  3.0568
#    RMS parameter:  1.8494
#    Parameters:
#      θ[ 0]=-2.1965 θ[ 1]= 0.0792 θ[ 2]=-2.2674 θ[ 3]=-2.1965
#      θ[ 4]=-0.8200 θ[ 5]=-2.0066 θ[ 6]= 2.2674 θ[ 7]= 2.2416
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 21
# ============================================================
# 📊 Energy = -38.78552542 Hartree
# 📊 Energy = -24338.2663 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.38799361 Hartree
# 📈 Energy improvement: 1.00807463 Hartree (632.5759 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.5139,  2.5139]
#    Parameter variance:  3.1684
#    RMS parameter:  1.8929
#    Parameters:
#      θ[ 0]=-1.9501 θ[ 1]=-0.1673 θ[ 2]=-2.5139 θ[ 3]=-1.9501
#      θ[ 4]=-1.0664 θ[ 5]=-2.2530 θ[ 6]= 2.5139 θ[ 7]= 1.9952
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 22
# ============================================================
# 📊 Energy = -37.64909760 Hartree
# 📊 Energy = -23625.1476 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -3.25156579 Hartree
# 📈 Energy improvement: -1.13642782 Hartree (-713.1187 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.7075,  2.7075]
#    Parameter variance:  3.3390
#    RMS parameter:  1.9484
#    Parameters:
#      θ[ 0]=-1.7564 θ[ 1]=-0.3610 θ[ 2]=-2.7075 θ[ 3]=-1.7564
#      θ[ 4]=-1.2601 θ[ 5]=-2.4467 θ[ 6]= 2.7075 θ[ 7]= 1.8015
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  7 energy=-37.64909760 ΔE=-1.188e+00 ak=7.748e-02 ck=1.232e-01
#
# ============================================================
# 🔄 VQE ITERATION 23
# ============================================================
# 📊 Energy = -34.50854953 Hartree
# 📊 Energy = -21654.4254 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -0.11101772 Hartree
# 📈 Energy improvement: -3.14054807 Hartree (-1970.7222 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.8291,  2.8291]
#    Parameter variance:  3.4517
#    RMS parameter:  1.9841
#    Parameters:
#      θ[ 0]=-1.8780 θ[ 1]=-0.4826 θ[ 2]=-2.8291 θ[ 3]=-1.6348
#      θ[ 4]=-1.1385 θ[ 5]=-2.5683 θ[ 6]= 2.8291 θ[ 7]= 1.9231
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 24
# ============================================================
# 📊 Energy = -39.40238303 Hartree
# 📊 Energy = -24725.3500 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.00485121 Hartree
# 📈 Energy improvement: 4.89383350 Hartree (3070.9246 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.5860,  2.5860]
#    Parameter variance:  3.2550
#    RMS parameter:  1.9197
#    Parameters:
#      θ[ 0]=-1.6348 θ[ 1]=-0.2394 θ[ 2]=-2.5860 θ[ 3]=-1.8780
#      θ[ 4]=-1.3817 θ[ 5]=-2.3251 θ[ 6]= 2.5860 θ[ 7]= 1.6799
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 25
# ============================================================
# 📊 Energy = -24.86974048 Hartree
# 📊 Energy = -15605.9860 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 9.52779133 Hartree
# 📈 Energy improvement: -14.53264254 Hartree (-9119.3640 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.8856,  3.6673]
#    Parameter variance:  4.1878
#    RMS parameter:  2.0924
#    Parameters:
#      θ[ 0]=-0.3175 θ[ 1]= 1.0779 θ[ 2]=-1.2687 θ[ 3]=-3.1953
#      θ[ 4]=-2.6990 θ[ 5]=-1.0078 θ[ 6]= 1.2687 θ[ 7]= 0.3626
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  8 energy=-24.86974048 ΔE=-1.278e+01 ak=7.150e-02 ck=1.216e-01
#
# ============================================================
# 🔄 VQE ITERATION 26
# ============================================================
# 📊 Energy = -23.45500135 Hartree
# 📊 Energy = -14718.2244 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 10.94253046 Hartree
# 📈 Energy improvement: -1.41473913 Hartree (-887.7615 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.0057,  3.7875]
#    Parameter variance:  4.3408
#    RMS parameter:  2.1418
#    Parameters:
#      θ[ 0]=-0.4377 θ[ 1]= 0.9577 θ[ 2]=-1.1485 θ[ 3]=-3.3154
#      θ[ 4]=-2.8191 θ[ 5]=-1.1280 θ[ 6]= 1.1485 θ[ 7]= 0.2425
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 27
# ============================================================
# 📊 Energy = -27.33851145 Hartree
# 📊 Energy = -17155.1620 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 7.05902037 Hartree
# 📈 Energy improvement: 3.88351010 Hartree (2436.9375 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.7654,  3.5472]
#    Parameter variance:  4.0565
#    RMS parameter:  2.0489
#    Parameters:
#      θ[ 0]=-0.1974 θ[ 1]= 1.1980 θ[ 2]=-1.3888 θ[ 3]=-3.0751
#      θ[ 4]=-2.5788 θ[ 5]=-0.8877 θ[ 6]= 1.3888 θ[ 7]= 0.4828
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 28
# ============================================================
# 📊 Energy = -41.88454730 Hartree
# 📊 Energy = -26282.9304 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.48701549 Hartree
# 📈 Energy improvement: 14.54603585 Hartree (9127.7684 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.8092,  2.5910]
#    Parameter variance:  3.7832
#    RMS parameter:  1.9477
#    Parameters:
#      θ[ 0]= 0.7589 θ[ 1]= 2.1543 θ[ 2]=-2.3451 θ[ 3]=-2.1189
#      θ[ 4]=-1.6226 θ[ 5]= 0.0685 θ[ 6]= 2.3451 θ[ 7]= 1.4390
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=  9 energy=-41.88454730 ΔE=1.701e+01 ak=6.660e-02 ck=1.201e-01
#
# ============================================================
# 🔄 VQE ITERATION 29
# ============================================================
# 📊 Energy = -40.09263064 Hartree
# 📊 Energy = -25158.4866 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.69509882 Hartree
# 📈 Energy improvement: -1.79191666 Hartree (-1124.4438 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.9281,  2.4721]
#    Parameter variance:  3.6485
#    RMS parameter:  1.9153
#    Parameters:
#      θ[ 0]= 0.8777 θ[ 1]= 2.2732 θ[ 2]=-2.2262 θ[ 3]=-2.0000
#      θ[ 4]=-1.5037 θ[ 5]= 0.1874 θ[ 6]= 2.2262 θ[ 7]= 1.5579
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 30
# ============================================================
# 📊 Energy = -43.78923217 Hartree
# 📊 Energy = -27478.1373 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -9.39170036 Hartree
# 📈 Energy improvement: 3.69660154 Hartree (2319.6507 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-2.6903,  2.7098]
#    Parameter variance:  3.9429
#    RMS parameter:  1.9867
#    Parameters:
#      θ[ 0]= 0.6400 θ[ 1]= 2.0354 θ[ 2]=-2.4639 θ[ 3]=-2.2378
#      θ[ 4]=-1.7414 θ[ 5]=-0.0503 θ[ 6]= 2.4639 θ[ 7]= 1.3201
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 31
# ============================================================
# 📊 Energy = -46.79442146 Hartree
# 📊 Energy = -29363.9206 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -12.39688964 Hartree
# 📈 Energy improvement: 3.00518928 Hartree (1885.7833 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.3170,  3.5629]
#    Parameter variance:  5.8263
#    RMS parameter:  2.4240
#    Parameters:
#      θ[ 0]=-0.2130 θ[ 1]= 1.1824 θ[ 2]=-3.3170 θ[ 3]=-3.0908
#      θ[ 4]=-2.5945 θ[ 5]=-0.9034 θ[ 6]= 3.3170 θ[ 7]= 0.4671
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 10 energy=-46.79442146 ΔE=4.910e+00 ak=6.251e-02 ck=1.189e-01
#
# ============================================================
# 🔄 VQE ITERATION 32
# ============================================================
# 📊 Energy = -45.45459442 Hartree
# 📊 Energy = -28523.1671 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -11.05706261 Hartree
# 📈 Energy improvement: -1.33982703 Hartree (-840.7535 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.2085,  3.4451]
#    Parameter variance:  5.7915
#    RMS parameter:  2.4207
#    Parameters:
#      θ[ 0]=-0.3308 θ[ 1]= 1.0646 θ[ 2]=-3.1992 θ[ 3]=-3.2085
#      θ[ 4]=-2.7122 θ[ 5]=-1.0211 θ[ 6]= 3.1992 θ[ 7]= 0.5849
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 33
# ============================================================
# 📊 Energy = -47.47920624 Hartree
# 📊 Energy = -29793.6292 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -13.08167443 Hartree
# 📈 Energy improvement: 2.02461181 Hartree (1270.4621 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.4347,  3.6806]
#    Parameter variance:  5.8857
#    RMS parameter:  2.4329
#    Parameters:
#      θ[ 0]=-0.0953 θ[ 1]= 1.3001 θ[ 2]=-3.4347 θ[ 3]=-2.9730
#      θ[ 4]=-2.4767 θ[ 5]=-0.7856 θ[ 6]= 3.4347 θ[ 7]= 0.3494
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 34
# ============================================================
# 📊 Energy = -41.97702323 Hartree
# 📊 Energy = -26340.9599 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.57949142 Hartree
# 📈 Energy improvement: -5.50218301 Hartree (-3452.6694 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.8244,  4.0703]
#    Parameter variance:  6.2583
#    RMS parameter:  2.5022
#    Parameters:
#      θ[ 0]= 0.2944 θ[ 1]= 1.6899 θ[ 2]=-3.8244 θ[ 3]=-2.5833
#      θ[ 4]=-2.0870 θ[ 5]=-0.3959 θ[ 6]= 3.8244 θ[ 7]=-0.0404
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 11 energy=-41.97702323 ΔE=-4.817e+00 ak=5.902e-02 ck=1.177e-01
#
# ============================================================
# 🔄 VQE ITERATION 35
# ============================================================
# 📊 Energy = -45.51321085 Hartree
# 📊 Energy = -28559.9494 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -11.11567904 Hartree
# 📈 Energy improvement: 3.53618762 Hartree (2218.9896 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.7077,  3.9536]
#    Parameter variance:  6.1129
#    RMS parameter:  2.4741
#    Parameters:
#      θ[ 0]= 0.1777 θ[ 1]= 1.8066 θ[ 2]=-3.7077 θ[ 3]=-2.7000
#      θ[ 4]=-1.9703 θ[ 5]=-0.5126 θ[ 6]= 3.7077 θ[ 7]= 0.0763
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 36
# ============================================================
# 📊 Energy = -38.48157435 Hartree
# 📊 Energy = -24147.5342 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.08404254 Hartree
# 📈 Energy improvement: -7.03163650 Hartree (-4412.4152 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.9411,  4.1870]
#    Parameter variance:  6.4280
#    RMS parameter:  2.5354
#    Parameters:
#      θ[ 0]= 0.4111 θ[ 1]= 1.5732 θ[ 2]=-3.9411 θ[ 3]=-2.4666
#      θ[ 4]=-2.2037 θ[ 5]=-0.2792 θ[ 6]= 3.9411 θ[ 7]=-0.1571
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 37
# ============================================================
# 📊 Energy = -32.22228448 Hartree
# 📊 Energy = -20219.7735 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 2.17524733 Hartree
# 📈 Energy improvement: -6.25928987 Hartree (-3927.7607 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.4014,  3.3772]
#    Parameter variance:  6.5113
#    RMS parameter:  2.6249
#    Parameters:
#      θ[ 0]=-1.3929 θ[ 1]= 3.3772 θ[ 2]=-2.1371 θ[ 3]=-4.2706
#      θ[ 4]=-0.3996 θ[ 5]=-2.0832 θ[ 6]= 2.1371 θ[ 7]= 1.6470
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 12 energy=-32.22228448 ΔE=-9.755e+00 ak=5.601e-02 ck=1.167e-01
#
# ============================================================
# 🔄 VQE ITERATION 38
# ============================================================
# 📊 Energy = -33.56790596 Hartree
# 📊 Energy = -21064.1631 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 0.82962585 Hartree
# 📈 Energy improvement: 1.34562148 Hartree (844.3896 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.2857,  3.4930]
#    Parameter variance:  6.5313
#    RMS parameter:  2.6199
#    Parameters:
#      θ[ 0]=-1.5087 θ[ 1]= 3.4930 θ[ 2]=-2.0213 θ[ 3]=-4.1549
#      θ[ 4]=-0.5154 θ[ 5]=-1.9675 θ[ 6]= 2.0213 θ[ 7]= 1.7627
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 39
# ============================================================
# 📊 Energy = -32.00766423 Hartree
# 📊 Energy = -20085.0974 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = 2.38986759 Hartree
# 📈 Energy improvement: -1.56024173 Hartree (-979.0657 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.5172,  3.2614]
#    Parameter variance:  6.5151
#    RMS parameter:  2.6349
#    Parameters:
#      θ[ 0]=-1.2771 θ[ 1]= 3.2614 θ[ 2]=-2.2529 θ[ 3]=-4.3864
#      θ[ 4]=-0.2839 θ[ 5]=-2.1990 θ[ 6]= 2.2529 θ[ 7]= 1.5312
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 40
# ============================================================
# 📊 Energy = -38.68723972 Hartree
# 📊 Energy = -24276.5911 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.28970791 Hartree
# 📈 Energy improvement: 6.67957550 Hartree (4191.4937 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.0417,  3.7369]
#    Parameter variance:  6.6516
#    RMS parameter:  2.6262
#    Parameters:
#      θ[ 0]=-1.7526 θ[ 1]= 3.7369 θ[ 2]=-1.7774 θ[ 3]=-3.9110
#      θ[ 4]=-0.7593 θ[ 5]=-1.7235 θ[ 6]= 1.7774 θ[ 7]= 2.0067
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 13 energy=-38.68723972 ΔE=6.465e+00 ak=5.338e-02 ck=1.158e-01
#
# ============================================================
# 🔄 VQE ITERATION 41
# ============================================================
# 📊 Energy = -37.04825409 Hartree
# 📊 Energy = -23248.1129 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -2.65072228 Hartree
# 📈 Energy improvement: -1.63898563 Hartree (-1028.4782 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.1566,  3.6220]
#    Parameter variance:  6.7059
#    RMS parameter:  2.6402
#    Parameters:
#      θ[ 0]=-1.8675 θ[ 1]= 3.6220 θ[ 2]=-1.6625 θ[ 3]=-4.0259
#      θ[ 4]=-0.6444 θ[ 5]=-1.8384 θ[ 6]= 1.8923 θ[ 7]= 1.8918
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 42
# ============================================================
# 📊 Energy = -39.84609225 Hartree
# 📊 Energy = -25003.7815 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.44856043 Hartree
# 📈 Energy improvement: 2.79783815 Hartree (1755.6686 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.9268,  3.8518]
#    Parameter variance:  6.6229
#    RMS parameter:  2.6172
#    Parameters:
#      θ[ 0]=-1.6377 θ[ 1]= 3.8518 θ[ 2]=-1.8923 θ[ 3]=-3.7961
#      θ[ 4]=-0.8742 θ[ 5]=-1.6086 θ[ 6]= 1.6625 θ[ 7]= 2.1216
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 43
# ============================================================
# 📊 Energy = -40.45217426 Hartree
# 📊 Energy = -25384.1034 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.05464245 Hartree
# 📈 Energy improvement: 0.60608202 Hartree (380.3219 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.9983,  4.3584]
#    Parameter variance:  6.8024
#    RMS parameter:  2.6374
#    Parameters:
#      θ[ 0]=-1.1311 θ[ 1]= 4.3584 θ[ 2]=-2.3989 θ[ 3]=-3.2895
#      θ[ 4]=-1.3808 θ[ 5]=-1.1021 θ[ 6]= 1.1559 θ[ 7]= 2.6282
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 14 energy=-40.45217426 ΔE=1.765e+00 ak=5.105e-02 ck=1.149e-01
#
# ============================================================
# 🔄 VQE ITERATION 44
# ============================================================
# 📊 Energy = -39.09076112 Hartree
# 📊 Energy = -24529.8044 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.69322930 Hartree
# 📈 Energy improvement: -1.36141314 Hartree (-854.2990 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-3.8842,  4.4725]
#    Parameter variance:  6.8601
#    RMS parameter:  2.6430
#    Parameters:
#      θ[ 0]=-1.0170 θ[ 1]= 4.4725 θ[ 2]=-2.5130 θ[ 3]=-3.4036
#      θ[ 4]=-1.2667 θ[ 5]=-0.9879 θ[ 6]= 1.0418 θ[ 7]= 2.7423
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 45
# ============================================================
# 📊 Energy = -40.97993473 Hartree
# 📊 Energy = -25715.2779 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.58240292 Hartree
# 📈 Energy improvement: 1.88917361 Hartree (1185.4734 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.1124,  4.2443]
#    Parameter variance:  6.7679
#    RMS parameter:  2.6368
#    Parameters:
#      θ[ 0]=-1.2452 θ[ 1]= 4.2443 θ[ 2]=-2.2848 θ[ 3]=-3.1754
#      θ[ 4]=-1.4949 θ[ 5]=-1.2162 θ[ 6]= 1.2700 θ[ 7]= 2.5140
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 46
# ============================================================
# 📊 Energy = -38.65723335 Hartree
# 📊 Energy = -24257.7618 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.25970154 Hartree
# 📈 Energy improvement: -2.32270138 Hartree (-1457.5160 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.4037,  3.9530]
#    Parameter variance:  6.7848
#    RMS parameter:  2.6576
#    Parameters:
#      θ[ 0]=-1.5365 θ[ 1]= 3.9530 θ[ 2]=-1.9935 θ[ 3]=-2.8841
#      θ[ 4]=-1.7862 θ[ 5]=-1.5074 θ[ 6]= 1.5613 θ[ 7]= 2.2228
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 15 energy=-38.65723335 ΔE=-1.795e+00 ak=4.897e-02 ck=1.141e-01
#
# ============================================================
# 🔄 VQE ITERATION 47
# ============================================================
# 📊 Energy = -39.60443843 Hartree
# 📊 Energy = -24852.1416 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.20690662 Hartree
# 📈 Energy improvement: 0.94720508 Hartree (594.3797 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.5171,  4.0664]
#    Parameter variance:  7.1647
#    RMS parameter:  2.7281
#    Parameters:
#      θ[ 0]=-1.6499 θ[ 1]= 4.0664 θ[ 2]=-1.8801 θ[ 3]=-2.9974
#      θ[ 4]=-1.8996 θ[ 5]=-1.3941 θ[ 6]= 1.4479 θ[ 7]= 2.3361
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 48
# ============================================================
# 📊 Energy = -37.89882606 Hartree
# 📊 Energy = -23781.8544 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -3.50129425 Hartree
# 📈 Energy improvement: -1.70561237 Hartree (-1070.2871 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.2903,  3.8396]
#    Parameter variance:  6.4307
#    RMS parameter:  2.5901
#    Parameters:
#      θ[ 0]=-1.4231 θ[ 1]= 3.8396 θ[ 2]=-2.1069 θ[ 3]=-2.7707
#      θ[ 4]=-1.6728 θ[ 5]=-1.6208 θ[ 6]= 1.6747 θ[ 7]= 2.1094
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 49
# ============================================================
# 📊 Energy = -41.80128668 Hartree
# 📊 Energy = -26230.6836 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.40375487 Hartree
# 📈 Energy improvement: 3.90246062 Hartree (2448.8292 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.7581,  4.3074]
#    Parameter variance:  8.0576
#    RMS parameter:  2.8871
#    Parameters:
#      θ[ 0]=-1.8909 θ[ 1]= 4.3074 θ[ 2]=-1.6392 θ[ 3]=-3.2384
#      θ[ 4]=-2.1405 θ[ 5]=-1.1531 θ[ 6]= 1.2070 θ[ 7]= 2.5771
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 16 energy=-41.80128668 ΔE=3.144e+00 ak=4.710e-02 ck=1.134e-01
#
# ============================================================
# 🔄 VQE ITERATION 50
# ============================================================
# 📊 Energy = -41.23573175 Hartree
# 📊 Energy = -25875.7928 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.83819993 Hartree
# 📈 Energy improvement: -0.56555494 Hartree (-354.8908 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.8707,  4.1947]
#    Parameter variance:  7.9459
#    RMS parameter:  2.8748
#    Parameters:
#      θ[ 0]=-2.0035 θ[ 1]= 4.1947 θ[ 2]=-1.5265 θ[ 3]=-3.3511
#      θ[ 4]=-2.0279 θ[ 5]=-1.2658 θ[ 6]= 1.0943 θ[ 7]= 2.6898
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 51
# ============================================================
# 📊 Energy = -42.26858105 Hartree
# 📊 Energy = -26523.9150 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.87104924 Hartree
# 📈 Energy improvement: 1.03284930 Hartree (648.1222 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.6454,  4.4200]
#    Parameter variance:  8.1918
#    RMS parameter:  2.9037
#    Parameters:
#      θ[ 0]=-1.7782 θ[ 1]= 4.4200 θ[ 2]=-1.7518 θ[ 3]=-3.1258
#      θ[ 4]=-2.2532 θ[ 5]=-1.0404 θ[ 6]= 1.3196 θ[ 7]= 2.4644
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 52
# ============================================================
# 📊 Energy = -42.54407442 Hartree
# 📊 Energy = -26696.7896 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.14654261 Hartree
# 📈 Energy improvement: 0.27549337 Hartree (172.8746 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.5499,  4.5155]
#    Parameter variance:  8.3233
#    RMS parameter:  2.9211
#    Parameters:
#      θ[ 0]=-1.6827 θ[ 1]= 4.5155 θ[ 2]=-1.8473 θ[ 3]=-3.0303
#      θ[ 4]=-2.3487 θ[ 5]=-0.9449 θ[ 6]= 1.4151 θ[ 7]= 2.3690
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 17 energy=-42.54407442 ΔE=7.428e-01 ak=4.542e-02 ck=1.127e-01
#
# ============================================================
# 🔄 VQE ITERATION 53
# ============================================================
# 📊 Energy = -42.42525549 Hartree
# 📊 Energy = -26622.2297 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.02772368 Hartree
# 📈 Energy improvement: -0.11881893 Hartree (-74.5599 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.5002,  4.6275]
#    Parameter variance:  8.5195
#    RMS parameter:  2.9545
#    Parameters:
#      θ[ 0]=-1.7947 θ[ 1]= 4.6275 θ[ 2]=-1.7353 θ[ 3]=-3.1423
#      θ[ 4]=-2.4607 θ[ 5]=-0.8329 θ[ 6]= 1.3031 θ[ 7]= 2.2569
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 54
# ============================================================
# 📊 Energy = -42.58273827 Hartree
# 📊 Energy = -26721.0515 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.18520645 Hartree
# 📈 Energy improvement: 0.15748277 Hartree (98.8219 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.6619,  4.4035]
#    Parameter variance:  8.1521
#    RMS parameter:  2.8917
#    Parameters:
#      θ[ 0]=-1.5707 θ[ 1]= 4.4035 θ[ 2]=-1.9593 θ[ 3]=-2.9183
#      θ[ 4]=-2.2367 θ[ 5]=-1.0569 θ[ 6]= 1.5271 θ[ 7]= 2.4810
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 55
# ============================================================
# 📊 Energy = -42.55875414 Hartree
# 📊 Energy = -26706.0013 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.16122233 Hartree
# 📈 Energy improvement: -0.02398413 Hartree (-15.0503 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.5807,  4.4847]
#    Parameter variance:  8.2736
#    RMS parameter:  2.9126
#    Parameters:
#      θ[ 0]=-1.6519 θ[ 1]= 4.4847 θ[ 2]=-1.8782 θ[ 3]=-2.9994
#      θ[ 4]=-2.3179 θ[ 5]=-0.9758 θ[ 6]= 1.4460 θ[ 7]= 2.3998
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 18 energy=-42.55875414 ΔE=1.468e-02 ak=4.388e-02 ck=1.120e-01
#
# ============================================================
# 🔄 VQE ITERATION 56
# ============================================================
# 📊 Energy = -42.93223555 Hartree
# 📊 Energy = -26940.3642 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.53470374 Hartree
# 📈 Energy improvement: 0.37348141 Hartree (234.3629 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-4.4693,  4.5961]
#    Parameter variance:  8.2355
#    RMS parameter:  2.9090
#    Parameters:
#      θ[ 0]=-1.7633 θ[ 1]= 4.5961 θ[ 2]=-1.7667 θ[ 3]=-3.1108
#      θ[ 4]=-2.4293 θ[ 5]=-1.0872 θ[ 6]= 1.3345 θ[ 7]= 2.2884
#      ... and 4 more parameters
#    ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2545110838.py in <cell line: 0>()
#      23 # Choose standard "normal VQE" starts: zero or random
#      24 init_basic = generic.get_initial_parameters('zero')  # or 'random_normal'
# ---> 25 params_basic, energy_basic = vqe_basic.run(init_basic)
#      26
#      27 # Report both raw and shift-adjusted energies for clarity
#
# /content/GroundStateFinder/vqeskeletal.py in run(self, initial_params, init_type)
#    1427
#    1428         # Run optimizer
# -> 1429         best_params = self.optimizer_plugin.optimize(self.objective_function, initial_params)
#    1430
#    1431         # Ensure we have energy for returned params (optimizer may store best earlier)
#
# /content/GroundStateFinder/vqeskeletal.py in optimize(self, objective_function, initial_params)
#     923             minus = params - ck * delta
#     924             e_plus = objective_function(plus)
# --> 925             e_minus = objective_function(minus)
#     926             # Gradient estimate (vector)
#     927             gk = (e_plus - e_minus) / (2.0 * ck) * delta
#
# /content/GroundStateFinder/vqeskeletal.py in objective_function(self, parameters)
#    1312         else:
#    1313             # Single-factor (legacy) path
# -> 1314             single_val = self._simulate_measurement(trial_wavefunction, hamiltonian)
#    1315             try:
#    1316                 single_val = float(single_val)
#
# /content/GroundStateFinder/vqeskeletal.py in _simulate_measurement(self, trial_wavefunction, hamiltonian)
#    1191             except TypeError:
#    1192                 job = self.estimator.run([(trial_wavefunction, hamiltonian)])
# -> 1193             estimator_result = job.result()
#    1194
#    1195             def collect_numbers(obj, depth=0, found=None):
#
# /usr/local/lib/python3.12/dist-packages/qiskit/primitives/primitive_job.py in result(self)
#      63         if self._result is None:
#      64             self._check_submitted()
# ---> 65             self._result = self._future.result()
#      66         return self._result
#      67
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Cell 6 Description: Hybrid VQE (SPSA → COBYLA, No ZNE, With Noise)
#
# Executes a two-phase optimization: global stochastic exploration via SPSA, then deterministic local refinement via COBYLA (forced switch), using the UCCSD ansatz from Cell 3. Simulates depolarizing noise on all gates. ZNE is not used here.

# %%
# === 6. Hybrid VQE (SPSA -> COBYLA, No ZNE, With Noise) ===
# Uses UCCSD ansatz from Cell 3 and simulates noise on all gates.
from vqeskeletal import HybridSPSAThenCOBYLA, ZNEDenoiserPlugin, VQE
from qiskit_aer.primitives import Estimator
from qiskit_aer.noise import NoiseModel, depolarizing_error

assert 'uccsd_ansatz' in globals(), 'Run the UCCSD ansatz build cell first.'
assert 'ham_system' in globals(), 'Run the Hamiltonian build cell first.'

def make_noise_model(p1=0.01, p2=0.02):
    model = NoiseModel()
    model.add_all_qubit_quantum_error(depolarizing_error(p1, 1), ['rx', 'ry', 'rz', 'x', 'y', 'z'])
    model.add_all_qubit_quantum_error(depolarizing_error(p2, 2), ['cx'])
    return model

noise_model = make_noise_model()
estimator = Estimator(backend_options={"noise_model": noise_model}, run_options={"shots": 2048})

class DirectHam:
    def __init__(self, sysd): self.sysd = sysd
    def get_hamiltonian(self): return self.sysd

hybrid_opt = HybridSPSAThenCOBYLA(spsa_iters=40, switch_tol=5e-3, min_spsa=12, force_cobyla=True, verbose=True)
no_zne2 = ZNEDenoiserPlugin(noise_factors=[1.0], verbose=False)

vqe_hybrid = VQE(uccsd_ansatz, DirectHam(ham_system), hybrid_opt, no_zne2, verbose=True, estimator=estimator)
init_hybrid = uccsd_ansatz.get_initial_parameters('random_small')
params_hybrid, energy_hybrid = vqe_hybrid.run(init_hybrid)
print('\n[Hybrid VQE] Final energy:', energy_hybrid)
# Out:
# 🔄 Initializing VQE system...
# ======================================================================
# BUILDING UCCSD ANSATZ FROM HAMILTONIAN
# ======================================================================
# System: qubits=6 spatial_orbs=3 particles=(2, 2)
# ✓ HF state ready (HartreeFock constructed)
# Ansatz depth=2 gates=5 params=8
# ✓ Ansatz construction complete (params=8)
#
# 🚀 Starting VQE optimization run
#    Parameter count: 8
#    Optimizer: HybridSPSAThenCOBYLA
# [Hybrid] Starting SPSA (max_iter=40) -> COBYLA (switch_tol=0.005)
#
# ============================================================
# 🔄 VQE ITERATION 1
# ============================================================
# 📊 Energy = -56.33987268 Hartree
# 📊 Energy = -35353.7772 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94234086 Hartree
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0133,  0.0049]
#    Parameter variance:  0.0000
#    RMS parameter:  0.0060
#    Parameters:
#      θ[ 0]= 0.0024 θ[ 1]= 0.0049 θ[ 2]=-0.0027 θ[ 3]=-0.0078
#      θ[ 4]=-0.0011 θ[ 5]=-0.0133 θ[ 6]= 0.0000 θ[ 7]= 0.0031
#    ==================================================
# [SPSA] Initial energy: -56.33987267591856
#
# ============================================================
# 🔄 VQE ITERATION 2
# ============================================================
# 📊 Energy = -54.49558730 Hartree
# 📊 Energy = -34196.4715 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.09805549 Hartree
# 📈 Energy improvement: -1.84428537 Hartree (-1157.3057 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1633,  0.1549]
#    Parameter variance:  0.0178
#    RMS parameter:  0.1523
#    Parameters:
#      θ[ 0]= 0.1524 θ[ 1]= 0.1549 θ[ 2]=-0.1527 θ[ 3]= 0.1422
#      θ[ 4]= 0.1489 θ[ 5]=-0.1633 θ[ 6]= 0.1500 θ[ 7]= 0.1531
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 3
# ============================================================
# 📊 Energy = -53.87921282 Hartree
# 📊 Energy = -33809.6910 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.48168100 Hartree
# 📈 Energy improvement: -0.61637449 Hartree (-386.7805 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1578,  0.1473]
#    Parameter variance:  0.0160
#    RMS parameter:  0.1479
#    Parameters:
#      θ[ 0]=-0.1476 θ[ 1]=-0.1451 θ[ 2]= 0.1473 θ[ 3]=-0.1578
#      θ[ 4]=-0.1511 θ[ 5]= 0.1367 θ[ 6]=-0.1500 θ[ 7]=-0.1469
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 4
# ============================================================
# 📊 Energy = -50.83968191 Hartree
# 📊 Energy = -31902.3580 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.44215009 Hartree
# 📈 Energy improvement: -3.03953091 Hartree (-1907.3330 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.4242,  0.4158]
#    Parameter variance:  0.1292
#    RMS parameter:  0.4131
#    Parameters:
#      θ[ 0]= 0.4133 θ[ 1]= 0.4158 θ[ 2]=-0.4137 θ[ 3]= 0.4031
#      θ[ 4]= 0.4098 θ[ 5]=-0.4242 θ[ 6]= 0.4109 θ[ 7]= 0.4140
#    ==================================================
# [SPSA] iter=  1 energy=-50.83968191 ΔE=-5.500e+00 ak=2.000e-01 ck=1.500e-01
#
# ============================================================
# 🔄 VQE ITERATION 5
# ============================================================
# 📊 Energy = -49.14727913 Hartree
# 📊 Energy = -30840.3600 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.74974732 Hartree
# 📈 Energy improvement: -1.69240278 Hartree (-1061.9980 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.5641,  0.5556]
#    Parameter variance:  0.2207
#    RMS parameter:  0.5269
#    Parameters:
#      θ[ 0]= 0.5532 θ[ 1]= 0.5556 θ[ 2]=-0.5535 θ[ 3]= 0.2632
#      θ[ 4]= 0.5497 θ[ 5]=-0.5641 θ[ 6]= 0.5508 θ[ 7]= 0.5539
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 6
# ============================================================
# 📊 Energy = -53.09998380 Hartree
# 📊 Energy = -33320.7177 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.70245198 Hartree
# 📈 Energy improvement: 3.95270467 Hartree (2480.3578 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2844,  0.5430]
#    Parameter variance:  0.0744
#    RMS parameter:  0.3208
#    Parameters:
#      θ[ 0]= 0.2735 θ[ 1]= 0.2759 θ[ 2]=-0.2738 θ[ 3]= 0.5430
#      θ[ 4]= 0.2700 θ[ 5]=-0.2844 θ[ 6]= 0.2711 θ[ 7]= 0.2742
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 7
# ============================================================
# 📊 Energy = -39.56734480 Hartree
# 📊 Energy = -24828.8650 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.16981299 Hartree
# 📈 Energy improvement: -13.53263900 Hartree (-8491.8528 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-1.4522,  2.2651]
#    Parameter variance:  2.4061
#    RMS parameter:  1.5731
#    Parameters:
#      θ[ 0]=-1.4487 θ[ 1]=-1.4462 θ[ 2]= 1.4484 θ[ 3]= 2.2651
#      θ[ 4]=-1.4522 θ[ 5]= 1.4378 θ[ 6]=-1.4511 θ[ 7]=-1.4480
#    ==================================================
# [SPSA] iter=  2 energy=-39.56734480 ΔE=-1.127e+01 ak=1.318e-01 ck=1.399e-01
#
# ============================================================
# 🔄 VQE ITERATION 8
# ============================================================
# 📊 Energy = -39.50242338 Hartree
# 📊 Energy = -24788.1262 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.10489157 Hartree
# 📈 Energy improvement: -0.06492142 Hartree (-40.7388 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-1.5853,  2.1309]
#    Parameter variance:  2.3782
#    RMS parameter:  1.5702
#    Parameters:
#      θ[ 0]=-1.3145 θ[ 1]=-1.5805 θ[ 2]= 1.5826 θ[ 3]= 2.1309
#      θ[ 4]=-1.3179 θ[ 5]= 1.3036 θ[ 6]=-1.5853 θ[ 7]=-1.5823
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 9
# ============================================================
# 📊 Energy = -39.54256667 Hartree
# 📊 Energy = -24813.3165 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.14503486 Hartree
# 📈 Energy improvement: 0.04014329 Hartree (25.1903 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-1.5864,  2.3994]
#    Parameter variance:  2.4678
#    RMS parameter:  1.5874
#    Parameters:
#      θ[ 0]=-1.5830 θ[ 1]=-1.3120 θ[ 2]= 1.3141 θ[ 3]= 2.3994
#      θ[ 4]=-1.5864 θ[ 5]= 1.5721 θ[ 6]=-1.3169 θ[ 7]=-1.3138
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 10
# ============================================================
# 📊 Energy = -39.55401904 Hartree
# 📊 Energy = -24820.5029 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.15648723 Hartree
# 📈 Energy improvement: 0.01145237 Hartree (7.1865 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-1.4676,  2.2806]
#    Parameter variance:  2.4115
#    RMS parameter:  1.5742
#    Parameters:
#      θ[ 0]=-1.4641 θ[ 1]=-1.4308 θ[ 2]= 1.4329 θ[ 3]= 2.2806
#      θ[ 4]=-1.4676 θ[ 5]= 1.4532 θ[ 6]=-1.4357 θ[ 7]=-1.4326
#    ==================================================
# [SPSA] iter=  3 energy=-39.55401904 ΔE=-1.333e-02 ak=1.032e-01 ck=1.342e-01
#
# ============================================================
# 🔄 VQE ITERATION 11
# ============================================================
# 📊 Energy = -38.69314591 Hartree
# 📊 Energy = -24280.2973 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.29561410 Hartree
# 📈 Energy improvement: -0.86087313 Hartree (-540.2056 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-1.5945,  2.4110]
#    Parameter variance:  2.4976
#    RMS parameter:  1.5885
#    Parameters:
#      θ[ 0]=-1.5945 θ[ 1]=-1.3004 θ[ 2]= 1.5633 θ[ 3]= 2.4110
#      θ[ 4]=-1.3372 θ[ 5]= 1.5836 θ[ 6]=-1.3053 θ[ 7]=-1.3022
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 12
# ============================================================
# 📊 Energy = -40.31116269 Hartree
# 📊 Energy = -25295.6174 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.91363087 Hartree
# 📈 Energy improvement: 1.61801678 Hartree (1015.3201 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-1.5980,  2.1502]
#    Parameter variance:  2.3403
#    RMS parameter:  1.5706
#    Parameters:
#      θ[ 0]=-1.3337 θ[ 1]=-1.5612 θ[ 2]= 1.3025 θ[ 3]= 2.1502
#      θ[ 4]=-1.5980 θ[ 5]= 1.3228 θ[ 6]=-1.5661 θ[ 7]=-1.5630
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 13
# ============================================================
# 📊 Energy = -43.20714453 Hartree
# 📊 Energy = -27112.8721 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.80961272 Hartree
# 📈 Energy improvement: 2.89598184 Hartree (1817.2547 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.0062,  1.7420]
#    Parameter variance:  2.2136
#    RMS parameter:  1.6284
#    Parameters:
#      θ[ 0]=-0.9256 θ[ 1]=-1.9694 θ[ 2]= 0.8943 θ[ 3]= 1.7420
#      θ[ 4]=-2.0062 θ[ 5]= 0.9147 θ[ 6]=-1.9743 θ[ 7]=-1.9712
#    ==================================================
# [SPSA] iter=  4 energy=-43.20714453 ΔE=3.653e+00 ak=8.681e-02 ck=1.304e-01
#
# ============================================================
# 🔄 VQE ITERATION 14
# ============================================================
# 📊 Energy = -41.62402603 Hartree
# 📊 Energy = -26119.4509 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.22649421 Hartree
# 📈 Energy improvement: -1.58311850 Hartree (-993.4211 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.1018,  1.6145]
#    Parameter variance:  2.1760
#    RMS parameter:  1.6041
#    Parameters:
#      θ[ 0]=-1.0530 θ[ 1]=-1.8419 θ[ 2]= 1.0218 θ[ 3]= 1.6145
#      θ[ 4]=-1.8787 θ[ 5]= 1.0421 θ[ 6]=-2.1018 θ[ 7]=-1.8437
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 15
# ============================================================
# 📊 Energy = -45.23526919 Hartree
# 📊 Energy = -28385.5385 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.83773738 Hartree
# 📈 Energy improvement: 3.61124316 Hartree (2266.0876 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.1337,  1.8695]
#    Parameter variance:  2.2816
#    RMS parameter:  1.6622
#    Parameters:
#      θ[ 0]=-0.7981 θ[ 1]=-2.0969 θ[ 2]= 0.7668 θ[ 3]= 1.8695
#      θ[ 4]=-2.1337 θ[ 5]= 0.7872 θ[ 6]=-1.8468 θ[ 7]=-2.0987
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 16
# ============================================================
# 📊 Energy = -46.16361298 Hartree
# 📊 Energy = -28968.0826 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -11.76608117 Hartree
# 📈 Energy improvement: 0.92834379 Hartree (582.5441 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-3.0811,  2.8169]
#    Parameter variance:  3.7419
#    RMS parameter:  2.1466
#    Parameters:
#      θ[ 0]= 0.1494 θ[ 1]=-3.0443 θ[ 2]=-0.1806 θ[ 3]= 2.8169
#      θ[ 4]=-3.0811 θ[ 5]=-0.1603 θ[ 6]=-0.8993 θ[ 7]=-3.0461
#    ==================================================
# [SPSA] iter=  5 energy=-46.16361298 ΔE=2.956e+00 ak=7.590e-02 ck=1.275e-01
#
# ============================================================
# 🔄 VQE ITERATION 17
# ============================================================
# 📊 Energy = -46.26781410 Hartree
# 📊 Energy = -29033.4698 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -11.87028228 Hartree
# 📈 Energy improvement: 0.10420112 Hartree (65.3871 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-3.1713,  2.9421]
#    Parameter variance:  3.8391
#    RMS parameter:  2.1431
#    Parameters:
#      θ[ 0]= 0.2746 θ[ 1]=-2.9192 θ[ 2]=-0.3058 θ[ 3]= 2.9421
#      θ[ 4]=-2.9560 θ[ 5]=-0.0351 θ[ 6]=-0.7742 θ[ 7]=-3.1713
#    ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-791463784.py in <cell line: 0>()
#      26 vqe_hybrid = VQE(uccsd_ansatz, DirectHam(ham_system), hybrid_opt, no_zne2, verbose=True, estimator=estimator)
#      27 init_hybrid = uccsd_ansatz.get_initial_parameters('random_small')
# ---> 28 params_hybrid, energy_hybrid = vqe_hybrid.run(init_hybrid)
#      29 print('\n[Hybrid VQE] Final energy:', energy_hybrid)
#
# /content/GroundStateFinder/vqeskeletal.py in run(self, initial_params, init_type)
#    1427
#    1428         # Run optimizer
# -> 1429         best_params = self.optimizer_plugin.optimize(self.objective_function, initial_params)
#    1430
#    1431         # Ensure we have energy for returned params (optimizer may store best earlier)
#
# /content/GroundStateFinder/vqeskeletal.py in optimize(self, objective_function, initial_params)
#    1026             return val
#    1027         # Run SPSA
# -> 1028         params_after_spsa = self._spsa.optimize(logging_objective, initial_params)
#    1029         # Decide on switch
#    1030         do_cobyla = self.force_cobyla
#
# /content/GroundStateFinder/vqeskeletal.py in optimize(self, objective_function, initial_params)
#     923             minus = params - ck * delta
#     924             e_plus = objective_function(plus)
# --> 925             e_minus = objective_function(minus)
#     926             # Gradient estimate (vector)
#     927             gk = (e_plus - e_minus) / (2.0 * ck) * delta
#
# /content/GroundStateFinder/vqeskeletal.py in logging_objective(p)
#    1022         energy_log = []
#    1023         def logging_objective(p):
# -> 1024             val = objective_function(p)
#    1025             energy_log.append(val)
#    1026             return val
#
# /content/GroundStateFinder/vqeskeletal.py in objective_function(self, parameters)
#    1312         else:
#    1313             # Single-factor (legacy) path
# -> 1314             single_val = self._simulate_measurement(trial_wavefunction, hamiltonian)
#    1315             try:
#    1316                 single_val = float(single_val)
#
# /content/GroundStateFinder/vqeskeletal.py in _simulate_measurement(self, trial_wavefunction, hamiltonian)
#    1191             except TypeError:
#    1192                 job = self.estimator.run([(trial_wavefunction, hamiltonian)])
# -> 1193             estimator_result = job.result()
#    1194
#    1195             def collect_numbers(obj, depth=0, found=None):
#
# /usr/local/lib/python3.12/dist-packages/qiskit/primitives/primitive_job.py in result(self)
#      63         if self._result is None:
#      64             self._check_submitted()
# ---> 65             self._result = self._future.result()
#      66         return self._result
#      67
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Cell 7 Description: Hybrid VQE with ZNE (Richardson, With Noise)
#
# Repeats the hybrid optimization but wraps each objective evaluation with a Zero Noise Extrapolation plugin using scaling factors [1,3,5] and Richardson extrapolation. Uses the UCCSD ansatz from Cell 3 and simulates depolarizing noise on all gates.

# %%
# === 7. Hybrid VQE + ZNE (Richardson, With Noise) ===
# Uses UCCSD ansatz from Cell 3, simulates noise, and applies ZNE on every iteration.
from vqeskeletal import ZNEDenoiserPlugin, VQE, HybridSPSAThenCOBYLA
from qiskit_aer.primitives import Estimator
from qiskit_aer.noise import NoiseModel, depolarizing_error

assert 'uccsd_ansatz' in globals(), 'Run the UCCSD ansatz build cell first.'
assert 'ham_system' in globals(), 'Run the Hamiltonian build cell first.'

def make_noise_model(p1=0.01, p2=0.02):
    model = NoiseModel()
    model.add_all_qubit_quantum_error(depolarizing_error(p1, 1), ['rx', 'ry', 'rz', 'x', 'y', 'z'])
    model.add_all_qubit_quantum_error(depolarizing_error(p2, 2), ['cx'])
    return model

noise_model = make_noise_model()
estimator = Estimator(backend_options={"noise_model": noise_model}, run_options={"shots": 2048})

class DirectHam:
    def __init__(self, sysd): self.sysd = sysd
    def get_hamiltonian(self): return self.sysd

zne_plugin = ZNEDenoiserPlugin(noise_factors=[1.0, 3.0, 5.0], extrapolation_method='richardson', verbose=True)
hybrid_opt2 = HybridSPSAThenCOBYLA(spsa_iters=40, switch_tol=5e-3, min_spsa=12, force_cobyla=True, verbose=True)

vqe_hybrid_zne = VQE(uccsd_ansatz, DirectHam(ham_system), hybrid_opt2, zne_plugin, verbose=True, estimator=estimator)
init_hybrid_zne = uccsd_ansatz.get_initial_parameters('random_small')
params_hybrid_zne, energy_hybrid_zne = vqe_hybrid_zne.run(init_hybrid_zne)
print('\n[Hybrid+ZNE VQE] Final (extrapolated) energy:', energy_hybrid_zne)
print('\nZNE analysis:', zne_plugin.get_zne_analysis())
# Out:
# 🔧 ZNE Plugin initialized:
#    Method: richardson
#    Noise factors: [1.0, 3.0, 5.0]
# 🔄 Initializing VQE system...
# ======================================================================
# BUILDING UCCSD ANSATZ FROM HAMILTONIAN
# ======================================================================
# System: qubits=6 spatial_orbs=3 particles=(2, 2)
# ✓ HF state ready (HartreeFock constructed)
# Ansatz depth=2 gates=5 params=8
# ✓ Ansatz construction complete (params=8)
#
# 🚀 Starting VQE optimization run
#    Parameter count: 8
#    Optimizer: HybridSPSAThenCOBYLA
# [Hybrid] Starting SPSA (max_iter=40) -> COBYLA (switch_tol=0.005)
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.32878695922411, -56.32878695922411, -56.32878695922411]
# 📊 ZNE Applied:
#    Noisy values: [-56.32878696 -56.32878696 -56.32878696]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.32878696
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 1
# ============================================================
# 📊 Energy = -56.32878696 Hartree
# 📊 Energy = -35346.8208 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93125515 Hartree
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0196,  0.0137]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0104
#    Parameters:
#      θ[ 0]= 0.0018 θ[ 1]=-0.0092 θ[ 2]=-0.0196 θ[ 3]= 0.0014
#      θ[ 4]= 0.0061 θ[ 5]= 0.0137 θ[ 6]=-0.0063 θ[ 7]= 0.0115
#    ==================================================
# [SPSA] Initial energy: -56.32878695922411
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-54.524725423997985, -54.524725423997985, -54.524725423997985]
# 📊 ZNE Applied:
#    Noisy values: [-54.52472542 -54.52472542 -54.52472542]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -54.52472542
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 2
# ============================================================
# 📊 Energy = -54.52472542 Hartree
# 📊 Energy = -34214.7559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.12719361 Hartree
# 📈 Energy improvement: -1.80406154 Hartree (-1132.0648 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1696,  0.1637]
#    Parameter variance:  0.0232
#    RMS parameter:  0.1569
#    Parameters:
#      θ[ 0]=-0.1482 θ[ 1]=-0.1592 θ[ 2]=-0.1696 θ[ 3]= 0.1514
#      θ[ 4]=-0.1439 θ[ 5]= 0.1637 θ[ 6]=-0.1563 θ[ 7]= 0.1615
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.94042480416207, -53.94042480416207, -53.94042480416207]
# 📊 ZNE Applied:
#    Noisy values: [-53.9404248 -53.9404248 -53.9404248]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.94042480
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 3
# ============================================================
# 📊 Energy = -53.94042480 Hartree
# 📊 Energy = -33848.1020 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.54289299 Hartree
# 📈 Energy improvement: -0.58430062 Hartree (-366.6539 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1486,  0.1561]
#    Parameter variance:  0.0192
#    RMS parameter:  0.1435
#    Parameters:
#      θ[ 0]= 0.1518 θ[ 1]= 0.1408 θ[ 2]= 0.1304 θ[ 3]=-0.1486
#      θ[ 4]= 0.1561 θ[ 5]=-0.1363 θ[ 6]= 0.1437 θ[ 7]=-0.1385
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.259305171269055, -51.259305171269055, -51.259305171269055]
# 📊 ZNE Applied:
#    Noisy values: [-51.25930517 -51.25930517 -51.25930517]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.25930517
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 4
# ============================================================
# 📊 Energy = -51.25930517 Hartree
# 📊 Energy = -32165.6753 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.86177336 Hartree
# 📈 Energy improvement: -2.68111963 Hartree (-1682.4267 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.4091,  0.4032]
#    Parameter variance:  0.1476
#    RMS parameter:  0.3963
#    Parameters:
#      θ[ 0]=-0.3877 θ[ 1]=-0.3987 θ[ 2]=-0.4091 θ[ 3]= 0.3909
#      θ[ 4]=-0.3835 θ[ 5]= 0.4032 θ[ 6]=-0.3959 θ[ 7]= 0.4010
#    ==================================================
# [SPSA] iter=  1 energy=-51.25930517 ΔE=-5.069e+00 ak=2.000e-01 ck=1.500e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-50.41356457037703, -50.41356457037703, -50.41356457037703]
# 📊 ZNE Applied:
#    Noisy values: [-50.41356457 -50.41356457 -50.41356457]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -50.41356457
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 5
# ============================================================
# 📊 Energy = -50.41356457 Hartree
# 📊 Energy = -31634.9655 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.01603276 Hartree
# 📈 Energy improvement: -0.84574060 Hartree (-530.7098 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.5357,  0.5431]
#    Parameter variance:  0.1722
#    RMS parameter:  0.4197
#    Parameters:
#      θ[ 0]=-0.5275 θ[ 1]=-0.2589 θ[ 2]=-0.2693 θ[ 3]= 0.5308
#      θ[ 4]=-0.2436 θ[ 5]= 0.5431 θ[ 6]=-0.5357 θ[ 7]= 0.2611
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-50.0784336896581, -50.0784336896581, -50.0784336896581]
# 📊 ZNE Applied:
#    Noisy values: [-50.07843369 -50.07843369 -50.07843369]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -50.07843369
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 6
# ============================================================
# 📊 Energy = -50.07843369 Hartree
# 📊 Energy = -31424.6678 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.68090188 Hartree
# 📈 Energy improvement: -0.33513088 Hartree (-210.2976 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.5490,  0.5409]
#    Parameter variance:  0.1596
#    RMS parameter:  0.4209
#    Parameters:
#      θ[ 0]=-0.2478 θ[ 1]=-0.5386 θ[ 2]=-0.5490 θ[ 3]= 0.2510
#      θ[ 4]=-0.5233 θ[ 5]= 0.2634 θ[ 6]=-0.2560 θ[ 7]= 0.5409
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-50.23148881760423, -50.23148881760423, -50.23148881760423]
# 📊 ZNE Applied:
#    Noisy values: [-50.23148882 -50.23148882 -50.23148882]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -50.23148882
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 7
# ============================================================
# 📊 Energy = -50.23148882 Hartree
# 📊 Energy = -31520.7113 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.83395700 Hartree
# 📈 Energy improvement: 0.15305513 Hartree (96.0435 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.5537,  0.5611]
#    Parameter variance:  0.1781
#    RMS parameter:  0.4259
#    Parameters:
#      θ[ 0]=-0.5456 θ[ 1]=-0.2409 θ[ 2]=-0.2513 θ[ 3]= 0.5488
#      θ[ 4]=-0.2256 θ[ 5]= 0.5611 θ[ 6]=-0.5537 θ[ 7]= 0.2431
#    ==================================================
# [SPSA] iter=  2 energy=-50.23148882 ΔE=-1.028e+00 ak=1.318e-01 ck=1.399e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.065605821641725, -51.065605821641725, -51.065605821641725]
# 📊 ZNE Applied:
#    Noisy values: [-51.06560582 -51.06560582 -51.06560582]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.06560582
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 8
# ============================================================
# 📊 Energy = -51.06560582 Hartree
# 📊 Energy = -32044.1272 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.66807401 Hartree
# 📈 Energy improvement: 0.83411700 Hartree (523.4159 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.6798,  0.6953]
#    Parameter variance:  0.2440
#    RMS parameter:  0.5023
#    Parameters:
#      θ[ 0]=-0.6798 θ[ 1]=-0.3751 θ[ 2]=-0.3855 θ[ 3]= 0.6830
#      θ[ 4]=-0.3598 θ[ 5]= 0.6953 θ[ 6]=-0.4195 θ[ 7]= 0.1089
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-48.77685096527356, -48.77685096527356, -48.77685096527356]
# 📊 ZNE Applied:
#    Noisy values: [-48.77685097 -48.77685097 -48.77685097]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -48.77685097
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 9
# ============================================================
# 📊 Energy = -48.77685097 Hartree
# 📊 Energy = -30607.9130 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.37931915 Hartree
# 📈 Energy improvement: -2.28875486 Hartree (-1436.2143 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.6880,  0.4269]
#    Parameter variance:  0.1459
#    RMS parameter:  0.3828
#    Parameters:
#      θ[ 0]=-0.4113 θ[ 1]=-0.1066 θ[ 2]=-0.1170 θ[ 3]= 0.4145
#      θ[ 4]=-0.0913 θ[ 5]= 0.4269 θ[ 6]=-0.6880 θ[ 7]= 0.3774
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-40.20909594440711, -40.20909594440711, -40.20909594440711]
# 📊 ZNE Applied:
#    Noisy values: [-40.20909594 -40.20909594 -40.20909594]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -40.20909594
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 10
# ============================================================
# 📊 Energy = -40.20909594 Hartree
# 📊 Energy = -25231.5696 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.81156413 Hartree
# 📈 Energy improvement: -8.56775502 Hartree (-5376.3434 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-1.4255,  1.4411]
#    Parameter variance:  1.2253
#    RMS parameter:  1.1413
#    Parameters:
#      θ[ 0]=-1.4255 θ[ 1]=-1.1208 θ[ 2]=-1.1313 θ[ 3]= 1.4288
#      θ[ 4]=-1.1056 θ[ 5]= 1.4411 θ[ 6]= 0.3262 θ[ 7]=-0.6368
#    ==================================================
# [SPSA] iter=  3 energy=-40.20909594 ΔE=-1.002e+01 ak=1.032e-01 ck=1.342e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2211017884.py in <cell line: 0>()
#      26 vqe_hybrid_zne = VQE(uccsd_ansatz, DirectHam(ham_system), hybrid_opt2, zne_plugin, verbose=True, estimator=estimator)
#      27 init_hybrid_zne = uccsd_ansatz.get_initial_parameters('random_small')
# ---> 28 params_hybrid_zne, energy_hybrid_zne = vqe_hybrid_zne.run(init_hybrid_zne)
#      29 print('\n[Hybrid+ZNE VQE] Final (extrapolated) energy:', energy_hybrid_zne)
#      30 print('\nZNE analysis:', zne_plugin.get_zne_analysis())
#
# /content/GroundStateFinder/vqeskeletal.py in run(self, initial_params, init_type)
#    1427
#    1428         # Run optimizer
# -> 1429         best_params = self.optimizer_plugin.optimize(self.objective_function, initial_params)
#    1430
#    1431         # Ensure we have energy for returned params (optimizer may store best earlier)
#
# /content/GroundStateFinder/vqeskeletal.py in optimize(self, objective_function, initial_params)
#    1026             return val
#    1027         # Run SPSA
# -> 1028         params_after_spsa = self._spsa.optimize(logging_objective, initial_params)
#    1029         # Decide on switch
#    1030         do_cobyla = self.force_cobyla
#
# /content/GroundStateFinder/vqeskeletal.py in optimize(self, objective_function, initial_params)
#     922             plus = params + ck * delta
#     923             minus = params - ck * delta
# --> 924             e_plus = objective_function(plus)
#     925             e_minus = objective_function(minus)
#     926             # Gradient estimate (vector)
#
# /content/GroundStateFinder/vqeskeletal.py in logging_objective(p)
#    1022         energy_log = []
#    1023         def logging_objective(p):
# -> 1024             val = objective_function(p)
#    1025             energy_log.append(val)
#    1026             return val
#
# /content/GroundStateFinder/vqeskeletal.py in objective_function(self, parameters)
#    1300                             print(f"[ZNE] Folding failed for factor {nf} ({e}); using original circuit.")
#    1301                         circ = trial_wavefunction
# -> 1302                 val = self._simulate_measurement(circ, hamiltonian)
#    1303                 # Coerce numeric
#    1304                 try:
#
# /content/GroundStateFinder/vqeskeletal.py in _simulate_measurement(self, trial_wavefunction, hamiltonian)
#    1191             except TypeError:
#    1192                 job = self.estimator.run([(trial_wavefunction, hamiltonian)])
# -> 1193             estimator_result = job.result()
#    1194
#    1195             def collect_numbers(obj, depth=0, found=None):
#
# /usr/local/lib/python3.12/dist-packages/qiskit/primitives/primitive_job.py in result(self)
#      63         if self._result is None:
#      64             self._check_submitted()
# ---> 65             self._result = self._future.result()
#      66         return self._result
#      67
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Cell 8 Description: Consolidated VQE Run Summary (Three Variants Only)
#
# Aggregates energies, best improvements, iteration counts, and parameter numbers for the three executed VQE variants: Simple VQE (hardware-efficient, with noise), Hybrid (SPSA->COBYLA, no ZNE, with noise), Hybrid+ZNE (with noise). Safe to rerun; skips variants not yet executed. Also prints ZNE extrapolation details if available.

# %%
# === 8. VQE Results Summary (Energies & Iterations, Three Variants Only) ===
# Collect and print final energies + iteration counts for each executed variant.
# Only includes: Simple VQE (hardware-efficient, with noise), Hybrid (SPSA->COBYLA, no ZNE, with noise), Hybrid+ZNE (with noise).

summary_rows = []
from math import isnan

def collect(label, vqe_obj, energy_name, energy_val):
    if vqe_obj is None:
        return
    final_energy = float(energy_val) if energy_val is not None else (
        vqe_obj.energy_history[-1] if vqe_obj.energy_history else float('nan')
    )
    best_energy = min(vqe_obj.energy_history) if vqe_obj.energy_history else final_energy
    iters = getattr(vqe_obj, 'iteration_count', len(getattr(vqe_obj,'energy_history', [])))
    params = getattr(getattr(vqe_obj, 'ansatz_plugin', object()), 'num_parameters', None)
    summary_rows.append({
        'variant': label,
        'final_energy': final_energy,
        'best_energy': best_energy,
        'iterations': iters,
        'parameters': params,
        'improvement': (vqe_obj.energy_history[0] - best_energy) if len(vqe_obj.energy_history) >= 2 else 0.0
    })

# Only collect the three requested variants
collect('Simple VQE (HEA, noise)', globals().get('vqe_simple'), 'energy_simple', globals().get('energy_simple'))
collect('Hybrid (SPSA->COBYLA, noise)', globals().get('vqe_hybrid'), 'energy_hybrid', globals().get('energy_hybrid'))
collect('Hybrid+ZNE (noise)', globals().get('vqe_hybrid_zne'), 'energy_hybrid_zne', globals().get('energy_hybrid_zne'))

if not summary_rows:
    print('No VQE runs detected yet. Run the variant cells first.')
else:
    print('\n=== VQE Run Summary ===')
    header = f"{'Variant':28s} {'Final Energy (Ha)':>18s} {'Best (Ha)':>14s} {'Δ (Ha)':>12s} {'Iters':>7s} {'Params':>7s}"""
    print(header)
    print('-'*len(header))
    for row in summary_rows:
        dE = row['improvement']
        print(f"{row['variant']:28s} {row['final_energy']:18.10f} {row['best_energy']:14.10f} {dE:12.6f} {row['iterations']:7d} {row['parameters']:7}")
    print('\nNotes:')
    print('  Δ (Ha) = initial_energy - best_energy (if multiple evaluations).')
    print('  Best vs Final can differ if last evaluation was not the minimum encountered.')
    if 'zne_plugin' in globals():
        zne_analysis = zne_plugin.get_zne_analysis()
        if 'error' not in zne_analysis:
            print('\nZNE summary (last run):')
            for k,v in zne_analysis.items():
                if isinstance(v, float):
                    print(f"  {k}: {v}")
                else:
                    print(f"  {k}: {v}")
        else:
            print('\nZNE summary: No multi-noise measurements collected (single-factor only).')
# Out:
# === VQE Run Summary ===
# Variant                       Final Energy (Ha)      Best (Ha)       Δ (Ha)   Iters  Params
# -------------------------------------------------------------------------------------------
# Simple VQE (HEA, noise)          -48.8258615066 -48.9408509570    48.940851      59      12
# Hybrid (SPSA->COBYLA, noise)     -46.2678140973 -56.3398726759     0.000000      17       8
# Hybrid+ZNE (noise)               -40.2090959444 -56.3287869592     0.000000      10       8
#
# Notes:
#   Δ (Ha) = initial_energy - best_energy (if multiple evaluations).
#   Best vs Final can differ if last evaluation was not the minimum encountered.
#
# ZNE summary (last run):
#   total_applications: 10
#   average_improvement: 0.0
#   std_improvement: 0.0
#   max_improvement: 0.0
#   min_improvement: 0.0
#   extrapolation_method: richardson
#   noise_factors: [1.0, 3.0, 5.0]
#   success_rate: 0.0

# %% [markdown]
# ### Gradio UI: Interactive Viewer for VQE Results and Artifacts
#
# This UI cell launches a small web app to explore outputs generated by the notebook. Run Cells 2–7 first so objects exist (ham_system, uccsd_ansatz, vqe_* variants, summary_rows). The UI provides:
#
# - Basic VQE tab: Streams a live energy-reduction plot from `vqe_basic.energy_history` and shows the final energy.
# - Hamiltonian Operator tab: Prints the first 10 non‑zero Pauli terms from `ham_system['hamiltonian_active']`.
# - UCCSD Ansatz Circuit tab: Renders the stored `uccsd_ansatz.ansatz_circuit`.
# - Optimizer Experiments tab: Shows five per‑variant energy plots (Baseline HF, CoordinateDescent, Basic (SPSA), Hybrid, Hybrid+ZNE) and an animated all‑variants comparison.
# - Extras tab: Simple note pad to save observations in‑session.
# - Summary Cell tab: Renders the markdown table created by the summary cell (final energy, best energy, iterations, params).
#
# Notes
# - The cell auto‑installs `gradio`, `matplotlib`, and `plotly` if missing.
# - On Colab it opens a public URL; locally it serves at http://127.0.0.1:7860 by default.
# - If a tab shows “N/A” or empties, run the corresponding compute cell (e.g., Basic/Hybrid/ZNE) and refresh the tab.

# %%
# === Download VQE Data as JSON ===
import json
from google.colab import files
from datetime import datetime

def get_vqe_summary():
    """Generate comprehensive VQE summary data for dashboard visualization."""
    results = []
    
    # Helper function to safely extract energy history
    def get_energy_history(vqe_obj):
        if hasattr(vqe_obj, 'energy_history') and vqe_obj.energy_history:
            return [float(e) for e in vqe_obj.energy_history]
        return []
    
    # Helper function to get iteration count
    def get_iteration_count(vqe_obj):
        if hasattr(vqe_obj, 'iteration_count'):
            return int(vqe_obj.iteration_count)
        elif hasattr(vqe_obj, 'energy_history'):
            return len(vqe_obj.energy_history)
        return 0
    
    # Simple VQE (Hardware-Efficient Ansatz with Noise)
    if 'vqe_simple' in globals() and vqe_simple is not None:
        energies = get_energy_history(vqe_simple)
        results.append({
            'variant': 'Simple VQE (HEA, noise)',
            'final_energy': energies[-1] if energies else None,
            'best_energy': min(energies) if energies else None,
            'energies': energies,
            'iterations': get_iteration_count(vqe_simple),
            'parameters': getattr(getattr(vqe_simple, 'ansatz_plugin', None), 'num_parameters', 0),
            'improvement': (energies[0] - min(energies)) if len(energies) > 1 else 0.0,
            'optimizer_type': 'SPSA',
            'ansatz_type': 'Hardware Efficient',
            'convergence_achieved': True,
            'noise_simulation': True
        })
    
    # Hybrid VQE (SPSA -> COBYLA, No ZNE, With Noise)
    if 'vqe_hybrid' in globals() and vqe_hybrid is not None:
        energies = get_energy_history(vqe_hybrid)
        results.append({
            'variant': 'Hybrid (SPSA->COBYLA, noise)',
            'final_energy': energies[-1] if energies else None,
            'best_energy': min(energies) if energies else None,
            'energies': energies,
            'iterations': get_iteration_count(vqe_hybrid),
            'parameters': getattr(getattr(vqe_hybrid, 'ansatz_plugin', None), 'num_parameters', 0),
            'improvement': (energies[0] - min(energies)) if len(energies) > 1 else 0.0,
            'optimizer_type': 'Hybrid (SPSA->COBYLA)',
            'ansatz_type': 'UCCSD',
            'convergence_achieved': True,
            'noise_simulation': True
        })
    
    # Hybrid VQE + ZNE (Richardson, With Noise)
    if 'vqe_hybrid_zne' in globals() and vqe_hybrid_zne is not None:
        energies = get_energy_history(vqe_hybrid_zne)
        results.append({
            'variant': 'Hybrid+ZNE (noise)',
            'final_energy': energies[-1] if energies else None,
            'best_energy': min(energies) if energies else None,
            'energies': energies,
            'iterations': get_iteration_count(vqe_hybrid_zne),
            'parameters': getattr(getattr(vqe_hybrid_zne, 'ansatz_plugin', None), 'num_parameters', 0),
            'improvement': (energies[0] - min(energies)) if len(energies) > 1 else 0.0,
            'optimizer_type': 'Hybrid (SPSA->COBYLA) + ZNE',
            'ansatz_type': 'UCCSD',
            'convergence_achieved': True,
            'noise_simulation': True,
            'zne_factors': [1.0, 3.0, 5.0] if 'zne_plugin' in globals() else None
        })
    
    # Add molecular system information to all results
    for result in results:
        result.update({
            'molecule': 'NH3',
            'basis_set': 'STO-3G',
            'active_space': f"{ELECTRONS_ALPHA + ELECTRONS_BETA} electrons, {ACTIVE_SPATIAL_ORBS} orbitals",
            'num_qubits': 2 * ACTIVE_SPATIAL_ORBS,
            'geometry': NH3_GEOM
        })
    
    print(f"Generated summary for {len(results)} VQE variants")
    return results

def download_vqe_data():
    """Generate and download VQE data as a JSON file."""
    vqe_data = {
        "metadata": {
            "timestamp": datetime.now().isoformat(),
            "notebook_version": "MAINCOLAB (1).ipynb",
            "molecular_system": "NH3 (Ammonia)",
            "basis_set": "STO-3G",
            "active_space": f"{ELECTRONS_ALPHA + ELECTRONS_BETA}e, {ACTIVE_SPATIAL_ORBS}o",
            "total_qubits": 2 * ACTIVE_SPATIAL_ORBS,
            "noise_simulation": True,
            "variants": ["Simple VQE (HEA, noise)", "Hybrid (SPSA->COBYLA, noise)", "Hybrid+ZNE (noise)"]
        },
        "results": get_vqe_summary()
    }
    
    # Generate filename with current date and time
    current_datetime = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    filename = f"vqe_results_{current_datetime}.json"
    
    # Save the JSON data to a file
    with open(filename, "w") as f:
        json.dump(vqe_data, f, indent=4)
    
    print(f"VQE data saved to {filename}")
    print(f"Total variants: {len(vqe_data['results'])}")
    
    # Download the file
    files.download(filename)

# Call the function to download the data
download_vqe_data()

# %%
# --- Gradio UI for VQE Workflow in Colab ---
# Install required packages (if not already installed)
try:
    import gradio as gr
except ImportError:
    # !pip install gradio --quiet
    import gradio as gr

try:
    import matplotlib.pyplot as plt
except ImportError:
    # !pip install matplotlib --quiet
    import matplotlib.pyplot as plt

try:
    import plotly.graph_objs as go
except ImportError:
    # !pip install plotly --quiet
    import plotly.graph_objs as go

try:
    from qiskit import QuantumCircuit
except ImportError:
    # !pip install qiskit --quiet
    from qiskit import QuantumCircuit

import numpy as np
import io
import time
import threading

# --- Helper Functions ---
def get_energy_history(vqe_obj):
    """Extract energy history from VQE object."""
    if hasattr(vqe_obj, 'energy_history'):
        return np.array(vqe_obj.energy_history)
    return np.array([])

def plot_energy_reduction(energy_history, title="Energy Reduction"):
    """Plot energy reduction over iterations using Matplotlib."""
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.plot(np.arange(1, len(energy_history)+1), energy_history, marker='o', color='blue')
    ax.set_xlabel("Iteration")
    ax.set_ylabel("Energy (Hartree)")
    ax.set_title(title)
    ax.grid(True)
    fig.tight_layout()
    return fig

def live_plot_energy_reduction(energy_history, title="Energy Reduction"):
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.set_xlabel("Iteration")
    ax.set_ylabel("Energy (Hartree)")
    ax.set_title(title)
    ax.grid(True)
    fig.tight_layout()
    for i in range(1, len(energy_history)+1):
        ax.clear()
        ax.plot(np.arange(1, i+1), energy_history[:i], marker='o', color='blue')
        ax.set_xlabel("Iteration")
        ax.set_ylabel("Energy (Hartree)")
        ax.set_title(title)
        ax.grid(True)
        fig.tight_layout()
        yield fig
        time.sleep(0.15)

def plot_comparison(energies, labels, title="VQE Variant Comparison"):
    """Plot comparison of final energies for different VQE variants."""
    fig = go.Figure()
    fig.add_trace(go.Bar(x=labels, y=energies, marker_color='indigo'))
    fig.update_layout(title=title, xaxis_title="Variant", yaxis_title="Final Energy (Hartree)", font_family="monospace")
    return fig

def live_text_reveal(text, delay=0.08):
    lines = text.split('\n')
    out = ""
    for line in lines:
        out += line + "\n"
        yield out
        time.sleep(delay)

def plot_all_histories(histories, labels, title):
    """Plot multiple energy histories for comparison with improved clarity."""
    fig, ax = plt.subplots(figsize=(12, 7))  # Larger figure for visibility
    colors = ["#e6194b", "#3cb44b", "#ffe119", "#4363d8", "#f58231", "#911eb4", "#46f0f0", "#f032e6"]
    markers = ['o', 's', '^', 'D', 'P', 'X', '*', 'v']
    for i, (hist, label) in enumerate(zip(histories, labels)):
        if len(hist) > 0:
            ax.plot(np.arange(1, len(hist)+1), hist, marker=markers[i % len(markers)], color=colors[i % len(colors)], label=label, linewidth=2, markersize=8)
    ax.set_xlabel("Iteration", fontsize=14)
    ax.set_ylabel("Energy (Hartree)", fontsize=14)
    ax.set_title(title, fontsize=16, fontweight='bold')
    ax.grid(True, which='both', linestyle='--', alpha=0.7)
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=13)  # Move legend outside plot
    fig.tight_layout(rect=[0, 0, 0.85, 1])  # Make room for legend
    return fig

def live_plot_all_histories(histories, labels, title):
    fig, ax = plt.subplots(figsize=(12, 7))
    colors = ["#e6194b", "#3cb44b", "#ffe119", "#4363d8", "#f58231", "#911eb4", "#46f0f0", "#f032e6"]
    markers = ['o', 's', '^', 'D', 'P', 'X', '*', 'v']
    ax.set_xlabel("Iteration", fontsize=14)
    ax.set_ylabel("Energy (Hartree)", fontsize=14)
    ax.set_title(title, fontsize=16, fontweight='bold')
    ax.grid(True, which='both', linestyle='--', alpha=0.7)
    fig.tight_layout(rect=[0, 0, 0.85, 1])
    max_len = max(len(hist) for hist in histories)
    for step in range(1, max_len+1):
        ax.clear()
        for i, (hist, label) in enumerate(zip(histories, labels)):
            if len(hist) >= step:
                ax.plot(np.arange(1, step+1), hist[:step], marker=markers[i % len(markers)], color=colors[i % len(colors)], label=label, linewidth=2, markersize=8)
            else:
                ax.plot(np.arange(1, len(hist)+1), hist, marker=markers[i % len(markers)], color=colors[i % len(colors)], label=label, linewidth=2, markersize=8)
        ax.set_xlabel("Iteration", fontsize=14)
        ax.set_ylabel("Energy (Hartree)", fontsize=14)
        ax.set_title(title, fontsize=16, fontweight='bold')
        ax.grid(True, which='both', linestyle='--', alpha=0.7)
        ax.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=13)
        fig.tight_layout(rect=[0, 0, 0.85, 1])
        yield fig
        time.sleep(0.15)

def get_hamiltonian_terms(ham_system, n_terms=10):
    """Return first n terms of the Hamiltonian as a formatted string."""
    qubit_op = ham_system['hamiltonian_active']
    labels = qubit_op.paulis.to_labels()
    coeffs = qubit_op.coeffs
    terms = [
        f"{coeff.real:+.8f} * {lbl}"
        for lbl, coeff in zip(labels, coeffs)
        if abs(complex(coeff)) > 1e-12
    ]
    return "\n".join(terms[:n_terms])

def get_ansatz_circuit(ansatz):
    """Visualize ansatz_circuit: mpl drawer if possible, else text drawer as image."""
    circ = getattr(ansatz, 'ansatz_circuit', None)
    if circ is None or not isinstance(circ, QuantumCircuit):
        return "Error: ansatz_circuit not found or not a QuantumCircuit object."
    try:
        fig = circ.draw(output='mpl', style={'fontsize': 10, 'font': 'monospace'})
        plt.close(fig)
        return fig
    except Exception as e:
        # Fallback: text drawer as image
        text = circ.draw(output='text')
        fig = plt.figure(figsize=(12, 4))
        plt.axis('off')
        plt.text(0.01, 0.5, str(text), fontsize=10, fontfamily='monospace', va='center', ha='left')
        plt.tight_layout()
        plt.close(fig)
        return fig

def get_summary_table(summary_rows):
    """Format summary table as markdown."""
    header = "| Variant | Final Energy (Ha) | Best (Ha) | Δ (Ha) | Iters | Params |\n|---|---|---|---|---|---|"
    rows = []
    for row in summary_rows:
        dE = row['improvement']
        rows.append(f"| {row['variant']} | {row['final_energy']:.8f} | {row['best_energy']:.8f} | {dE:.6f} | {row['iterations']} | {row['parameters']} |")
    return header + "\n" + "\n".join(rows)

# --- Load objects from Colab session ---
# These should be available if you have run the notebook cells.
# If not, you can run the notebook cells first.

# --- Gradio UI ---
PIXEL_FONT_URL = "https://fonts.googleapis.com/css2?family=Press+Start+2P&display=swap"
pixel_font_css = (
    "@import url('" + PIXEL_FONT_URL + "');\n"
    ".gradio-container, .gradio-markdown, .gradio-input, .gradio-output, .gradio-button, .gradio-label, .gradio-plot, .gradio-textbox, .gradio-tab, .gradio-radio, .gradio-checkbox, .gradio-dropdown, .gradio-table, .gradio-html, .gradio-markdown h1, .gradio-markdown h2, .gradio-markdown h3, .gradio-markdown h4, .gradio-markdown h5, .gradio-markdown h6 {\n"
    "    font-family: 'Press Start 2P', 'monospace', 'Menlo', 'Roboto Mono', monospace !important;\n"
    "    letter-spacing: 1px;\n"
    "    font-size: 13px !important;\n"
    "}\n"
    ".gradio-button {\n"
    "    font-size: 13px !important;\n"
    "    padding: 8px 18px !important;\n"
    "    border-radius: 6px !important;\n"
    "    background: #222 !important;\n"
    "    color: #fff !important;\n"
    "    border: 2px solid #888 !important;\n"
    "    box-shadow: 2px 2px 0 #888;\n"
    "}\n"
    "footer {visibility: hidden;}\n"
    )

with gr.Blocks(theme="soft", css=pixel_font_css) as demo:
    gr.Markdown("# NEBULA : Enhanced VQE: Hybrid Initialization, Adaptive Optimization & Noise Mitigation")


    with gr.Tab("Basic VQE"):
        btn_basic = gr.Button("Show Basic VQE Results")
        gr.Markdown("### Energy Reduction Step-by-Step")
        energy_plot = gr.Plot(label="Energy Reduction Graph")
        final_energy = gr.Textbox(label="Final Computed Energy", interactive=False)

        def show_basic_vqe():
            energy_hist = get_energy_history(globals().get('vqe_basic'))
            if len(energy_hist) == 0:
                yield None, "N/A"
                return
            for fig in live_plot_energy_reduction(energy_hist, "Basic VQE Energy Reduction"):
                yield fig, ""
            yield fig, str(energy_hist[-1])
        btn_basic.click(show_basic_vqe, outputs=[energy_plot, final_energy])

    with gr.Tab("Hamiltonian Operator"):
        btn_ham = gr.Button("Show Hamiltonian Terms")
        gr.Markdown("### First 10 Terms of Hamiltonian")
        hamiltonian_terms = gr.Textbox(label="Hamiltonian Terms", lines=12, interactive=False)

        def show_hamiltonian():
            ham = globals().get('ham_system')
            if ham:
                terms = get_hamiltonian_terms(ham, 10)
            else:
                terms = "Hamiltonian not found. Run Cell 2 in notebook."
            for partial in live_text_reveal(terms):
                yield partial
        btn_ham.click(show_hamiltonian, outputs=hamiltonian_terms)

    with gr.Tab("UCCSD Ansatz Circuit"):
        btn_circuit = gr.Button("Show UCCSD Circuit")
        gr.Markdown("### UCCSD Ansatz Circuit Visualization")
        circuit_plot = gr.Plot(label="UCCSD Circuit")

        def show_circuit():
            ansatz = globals().get('uccsd_ansatz')
            if ansatz:
                fig = get_ansatz_circuit(ansatz)
                yield fig
            else:
                yield "Ansatz not found. Run Cell 3 in notebook."
        btn_circuit.click(show_circuit, outputs=circuit_plot)

    with gr.Tab("Optimizer Experiments"):
        btn_all = gr.Button("Show All Comparison Graphs")
        gr.Markdown("### Compare Optimizer Variants (5 Graphs)")
        graph1 = gr.Plot(label="Baseline HF Energy ")
        graph2 = gr.Plot(label="CoordinateDescent Energy ")
        graph3 = gr.Plot(label="Basic (SPSA) Energy ")
        graph4 = gr.Plot(label="Hybrid (SPSA->COBYLA) Energy ")
        graph5 = gr.Plot(label="Hybrid+ZNE Energy ")
        all_graph = gr.Plot(label="All Variants Comparison")

        def show_all_graphs():
            variants = [
                ('Baseline HF', 'baseline_obj'),
                ('CoordinateDescent', 'vqe_cd'),
                ('Basic (SPSA)', 'vqe_basic'),
                ('Hybrid (SPSA->COBYLA)', 'vqe_hybrid'),
                ('Hybrid+ZNE', 'vqe_hybrid_zne')
            ]
            histories = []
            figs = []
            # Show all 5 graphs as static images first
            for label, obj_name in variants:
                obj = globals().get(obj_name)
                hist = get_energy_history(obj) if obj else np.array([])
                histories.append(hist)
                figs.append(plot_energy_reduction(hist, f"{label} Energy "))
            yield figs[0], figs[1], figs[2], figs[3], figs[4], None
            # Animate all variants comparison
            for all_fig in live_plot_all_histories(histories, [v[0] for v in variants], "All VQE Variants Energy Comparison"):
                yield figs[0], figs[1], figs[2], figs[3], figs[4], all_fig
            # Final output
            all_fig = plot_all_histories(histories, [v[0] for v in variants], "All VQE Variants Energy Comparison")
            yield figs[0], figs[1], figs[2], figs[3], figs[4], all_fig
        btn_all.click(show_all_graphs, outputs=[graph1, graph2, graph3, graph4, graph5, all_graph])

    with gr.Tab("Summary Cell"):
        btn_summary = gr.Button("Show Summary Table")
        gr.Markdown("### VQE Results Summary Table")
        summary_md = gr.Markdown()

        def show_summary():
            rows = globals().get('summary_rows', [])
            if rows:
                table = get_summary_table(rows)
            else:
                table = "No summary available. Run summary cell in notebook."
            for partial in live_text_reveal(table):
                yield partial
        btn_summary.click(show_summary, outputs=summary_md)

    with gr.Tab("Extras"):
        btn_notes = gr.Button("Save Note")
        gr.Markdown("### Add Notes or Observations")
        notes = gr.Textbox(label="Your Notes", lines=6, interactive=True)
        notes_display = gr.Markdown()

        def save_note(note):
            return f"**Your Note:**\n\n{note}"
        btn_notes.click(save_note, inputs=notes, outputs=notes_display)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4743e6296621e17942.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4743e6296621e17942.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
